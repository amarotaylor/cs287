# %% [markdown]
# # CS 287, Homework 3: Neural Machine Translation

# %%
import torch
from torch.nn.utils import clip_grad_norm_
torch.__version__
from common import *
## Setup
import torch.nn.functional as F

#!pip install --upgrade pip
#!pip install -q numpy

#!pip install -q torch torchtext spacy opt_einsum
#!pip install -qU git+https://github.com/harvardnlp/namedtensor
#!python -m spacy download en
#!python -m spacy download de

# Torch
import torch.nn as nn
import torch
# Text text processing library and methods for pretrained word embeddings
from torchtext import data, datasets
# Named Tensor wrappers
from namedtensor import ntorch, NamedTensor
from namedtensor.text import NamedField
import numpy as np
# %reload_ext autoreload
# %autoreload 2

# %%
# split raw data into tokens
import spacy
spacy_de = spacy.load('de')
spacy_en = spacy.load('en')

def tokenize_de(text):
    return [tok.text for tok in spacy_de.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

# add beginning-of-sentence and end-of-sentence tokens to target
BOS_WORD = '<s>'
EOS_WORD = '</s>'
DE = NamedField(names=('srcSeqlen',), tokenize=tokenize_de)
EN = NamedField(names=('trgSeqlen',), tokenize=tokenize_en,
                init_token = BOS_WORD, eos_token = EOS_WORD) # only target needs BOS/EOS

# download dataset of 200K pairs of sentences
# start with MAXLEN = 20
MAX_LEN = 20
train, val, test = datasets.IWSLT.splits(exts=('.de', '.en'), fields=(DE, EN), 
                                         filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and 
                                         len(vars(x)['trg']) <= MAX_LEN)
print(train.fields)
print(len(train))
print(vars(train[0]))

# WHAT DOES THIS DO?
'''src = open("valid.src", "w")
trg = open("valid.trg", "w")
for example in val:
    print(" ".join(example.src), file=src)
    print(" ".join(example.trg), file=trg)
src.close()
trg.close()'''

# build vocab, convert words to indices
MIN_FREQ = 5
DE.build_vocab(train.src, min_freq=MIN_FREQ)
EN.build_vocab(train.trg, min_freq=MIN_FREQ)
print(DE.vocab.freqs.most_common(10))
print("Size of German vocab", len(DE.vocab))
print(EN.vocab.freqs.most_common(10))
print("Size of English vocab", len(EN.vocab))
print(EN.vocab.stoi["<s>"], EN.vocab.stoi["</s>"])

print(EN.vocab.stoi["<pad>"], EN.vocab.stoi["<unk>"])
# Out:
# {'src': <namedtensor.text.torch_text.NamedField object at 0x7f4516a8bf28>, 'trg': <namedtensor.text.torch_text.NamedField object at 0x7f451024b9e8>}
# 119076
# {'src': ['David', 'Gallo', ':', 'Das', 'ist', 'Bill', 'Lange', '.', 'Ich', 'bin', 'Dave', 'Gallo', '.'], 'trg': ['David', 'Gallo', ':', 'This', 'is', 'Bill', 'Lange', '.', 'I', "'m", 'Dave', 'Gallo', '.']}
# [('.', 113253), (',', 67237), ('ist', 24189), ('die', 23778), ('das', 17102), ('der', 15727), ('und', 15622), ('Sie', 15085), ('es', 13197), ('ich', 12946)]
# Size of German vocab 13353
# [('.', 113433), (',', 59512), ('the', 46029), ('to', 29177), ('a', 27548), ('of', 26794), ('I', 24887), ('is', 21775), ("'s", 20630), ('that', 19814)]
# Size of English vocab 11560
# 2 3
# 1 0

# %%
# split data into batches
BATCH_SIZE = 32
device = torch.device('cuda:0')
train_iter, val_iter = data.BucketIterator.splits((train, val), batch_size=BATCH_SIZE, device=device,
                                                  repeat=False, sort_key=lambda x: len(x.src))

# %% [markdown]
# ## Sequence to Sequence Learning with Neural Networks

# %% [markdown]
# - English to French translation, $p \left( y_1, \dots, y_{T'} \ | \ x_1, \dots, x_T \right) = \prod_{t = 1}^{T'} p \left( y_t \ | \ v, y_1, \dots, y_{t-1} \right)$
# - Each sentence ends in '<EOS\>', out-of-vocab words denoted '<UNK\>'
# - Model specs:
#     * Input vocabulary of 160,000 and output vocabulary of 80,000
#     * Deep LSTM to map (encode) input sequence to fixed-len vector
#     * Another deep LSTM to translate (decode) fixed-len vector to output sequence
#     * 4 layers per LSTM, 1000 cells per layer, 1000-dimensional word embeddings, softmax over 80,000 words
#     * Reversing order of words in source (but not target) improved performance
#         * Each word in the source is far from its corresponding word in the target (large minimal time lag); reversing the source reduces the minimal time lag, thereby allowing backprop to establish communication between source and target more easily
# - Training specs:
#     * Initialize all LSTM params $\sim Unif[-0.08,0.08]$
#     * SGD w/o momentum, lr = 0.7
#         * After 5 epochs, halve the lr every half-epoch
#         * Train for 7.5 epochs
#     * Batch size = 128; divide gradient by batch size (denoted $g$)
#     * Hard constraint gradient norm; if $s = ||g||_2 > 5$, set $s = 5$
#     * Make sure all sentences within a minibatch are roughly the same length
# - Objective: $max \frac{1}{|S|} \sum_{(T,S) \in \mathcal{S}} log \ p(T \ | \ S)$, where $\mathcal{S}$ is the training set
# - Prediction: $\hat{T} = argmax \ p(T \ | \ S)$ via beam search, where beam size $B \in {1,2}$

# %%
context_size = 500
num_layers = 2
seq2context = SequenceModel(len(DE.vocab),context_size,num_layers=2)
context2trg = RNNet(input_size=len(EN.vocab),hidden_size=context_size,num_layers=2,weight_tie=True)

seq2context,context2trg = seq2context.cuda(),context2trg.cuda()
seq2context_optimizer = torch.optim.Adam(seq2context.parameters(), lr=0.001)
context2trg_optimizer = torch.optim.Adam(context2trg.parameters(), lr=0.001)

scheduler_c2t = torch.optim.lr_scheduler.ReduceLROnPlateau(context2trg_optimizer, mode="min", patience=5)
scheduler_s2c = torch.optim.lr_scheduler.ReduceLROnPlateau(seq2context_optimizer, mode="min", patience=5)

# %%
best_ppl = 1e8
for e in range(300):
    training_loop(e,train_iter,seq2context,context2trg,seq2context_optimizer,context2trg_optimizer,BATCH_SIZE)
    ppl = validation_loop(e,val_iter,seq2context,context2trg,scheduler_s2c,scheduler_c2t,BATCH_SIZE)
    if ppl < best_ppl:
        
        torch.save(seq2context.state_dict(),'best_seq2seq_seq2context.pt')
        torch.save(context2trg.state_dict(),'best_seq2seq_context2trg.pt')
        best_ppl = ppl
        print('Wrote model!')
# Out:
# Epoch: 0, Batch: 0, Loss: 72.89492797851562, Variance: 10.60205078125
# Epoch: 0, Batch: 100, Loss: 72.35356140136719, Variance: 16.461355209350586
# Epoch: 0, Batch: 200, Loss: 53.555816650390625, Variance: 81.23693084716797
# Epoch: 0, Batch: 300, Loss: 62.14815902709961, Variance: 93.3572998046875
# Epoch: 0, Batch: 400, Loss: 60.69529724121094, Variance: 110.68404388427734
# Epoch: 0, Batch: 500, Loss: 59.723941802978516, Variance: 112.48945617675781
# Epoch: 0, Batch: 600, Loss: 60.40635299682617, Variance: 167.12879943847656
# Epoch: 0, Batch: 700, Loss: 62.23527526855469, Variance: 222.0726318359375
# Epoch: 0, Batch: 800, Loss: 51.462223052978516, Variance: 635.3838500976562
# Epoch: 0, Batch: 900, Loss: 56.13264465332031, Variance: 1230.6614990234375
# Epoch: 0, Batch: 1000, Loss: 57.61231994628906, Variance: 463.8847351074219
# Epoch: 0, Batch: 1100, Loss: 60.117408752441406, Variance: 1062.3524169921875
# Epoch: 0, Batch: 1200, Loss: 61.13800048828125, Variance: 307.99530029296875
# Epoch: 0, Batch: 1300, Loss: 61.01355743408203, Variance: 1135.6917724609375
# Epoch: 0, Batch: 1400, Loss: 59.326351165771484, Variance: 510.8633728027344
# Epoch: 0, Batch: 1500, Loss: 54.916465759277344, Variance: 837.3878784179688
# Epoch: 0, Batch: 1600, Loss: 57.7711181640625, Variance: 1130.7705078125
# Epoch: 0, Batch: 1700, Loss: 49.28116989135742, Variance: 4486.8662109375
# Epoch: 0, Batch: 1800, Loss: 54.025123596191406, Variance: 4168.82666015625
# Epoch: 0, Batch: 1900, Loss: 52.21171569824219, Variance: 4404.2861328125
# Epoch: 0, Batch: 2000, Loss: 58.34761428833008, Variance: 824.2250366210938
# Epoch: 0, Batch: 2100, Loss: 60.269493103027344, Variance: 1126.4952392578125
# Epoch: 0, Batch: 2200, Loss: 55.088096618652344, Variance: 624.2554321289062
# Epoch: 0, Batch: 2300, Loss: 54.6758918762207, Variance: 1769.8101806640625
# Epoch: 0, Batch: 2400, Loss: 51.99040985107422, Variance: 3957.0625
# Epoch: 0, Batch: 2500, Loss: 58.380855560302734, Variance: 981.7947387695312
# Epoch: 0, Batch: 2600, Loss: 55.29755783081055, Variance: 705.1370239257812
# Epoch: 0, Batch: 2700, Loss: 45.33484649658203, Variance: 1038.093505859375
# Epoch: 0, Batch: 2800, Loss: 55.29957580566406, Variance: 1474.4722900390625
# Epoch: 0, Batch: 2900, Loss: 51.55146026611328, Variance: 3328.210205078125
# Epoch: 0, Batch: 3000, Loss: 51.760005950927734, Variance: 1234.2188720703125
# Epoch: 0, Batch: 3100, Loss: 52.418067932128906, Variance: 1827.025146484375
# Epoch: 0, Batch: 3200, Loss: 55.20823669433594, Variance: 1733.9249267578125
# Epoch: 0, Batch: 3300, Loss: 50.42341995239258, Variance: 2565.396484375
# Epoch: 0, Batch: 3400, Loss: 58.094154357910156, Variance: 3909.081787109375
# Epoch: 0, Batch: 3500, Loss: 54.3548469543457, Variance: 16909.1171875
# Epoch: 0, Batch: 3600, Loss: 53.03913116455078, Variance: 1493.6495361328125
# Epoch: 0, Batch: 3700, Loss: 46.655738830566406, Variance: 1541.629638671875
# Epoch: 0, Validation loss: 43.255775451660156, Validation ppl: 38.85019302368164
# Wrote model!
# Epoch: 1, Batch: 0, Loss: 49.61603546142578, Variance: 1731.6873779296875
# Epoch: 1, Batch: 100, Loss: 49.46013641357422, Variance: 2352.779052734375
# Epoch: 1, Batch: 200, Loss: 49.226158142089844, Variance: 2357.9521484375
# Epoch: 1, Batch: 300, Loss: 48.27472686767578, Variance: 21980.970703125
# Epoch: 1, Batch: 400, Loss: 53.03730773925781, Variance: 7135.72021484375
# Epoch: 1, Batch: 500, Loss: 53.58018493652344, Variance: 2486.382568359375
# Epoch: 1, Batch: 600, Loss: 53.596656799316406, Variance: 8449.2490234375
# Epoch: 1, Batch: 700, Loss: 47.33381652832031, Variance: 4134.53076171875
# Epoch: 1, Batch: 800, Loss: 44.76512145996094, Variance: 6062.66064453125
# Epoch: 1, Batch: 900, Loss: 48.49803924560547, Variance: 9929.7734375
# Epoch: 1, Batch: 1000, Loss: 44.44251251220703, Variance: 2426.47265625
# Epoch: 1, Batch: 1100, Loss: 43.70792007446289, Variance: 3009.22900390625
# Epoch: 1, Batch: 1200, Loss: 47.62654113769531, Variance: 3630.00537109375
# Epoch: 1, Batch: 1300, Loss: 46.73928451538086, Variance: 5085.9560546875
# Epoch: 1, Batch: 1400, Loss: 49.00403594970703, Variance: 6912.4853515625
# Epoch: 1, Batch: 1500, Loss: 56.22532272338867, Variance: 40590.765625
# Epoch: 1, Batch: 1600, Loss: 47.77207565307617, Variance: 13381.572265625
# Epoch: 1, Batch: 1700, Loss: 42.1534423828125, Variance: 2302.44140625
# Epoch: 1, Batch: 1800, Loss: 50.15409851074219, Variance: 7863.0693359375
# Epoch: 1, Batch: 1900, Loss: 53.449485778808594, Variance: 3870.50732421875
# Epoch: 1, Batch: 2000, Loss: 42.404884338378906, Variance: 7427.63525390625
# Epoch: 1, Batch: 2100, Loss: 49.41703796386719, Variance: 13014.40234375
# Epoch: 1, Batch: 2200, Loss: 46.515621185302734, Variance: 6061.162109375
# Epoch: 1, Batch: 2300, Loss: 50.84172821044922, Variance: 2882.71044921875
# Epoch: 1, Batch: 2400, Loss: 43.814430236816406, Variance: 4042.32421875
# Epoch: 1, Batch: 2500, Loss: 47.50463104248047, Variance: 23095.41015625
# Epoch: 1, Batch: 2600, Loss: 48.77753448486328, Variance: 3473.645751953125
# Epoch: 1, Batch: 2700, Loss: 45.813934326171875, Variance: 9755.650390625
# Epoch: 1, Batch: 2800, Loss: 53.6884880065918, Variance: 4264.48046875
# Epoch: 1, Batch: 2900, Loss: 49.406158447265625, Variance: 3697.01123046875
# Epoch: 1, Batch: 3000, Loss: 41.01118469238281, Variance: 7128.79736328125
# Epoch: 1, Batch: 3100, Loss: 50.99184799194336, Variance: 9022.8232421875
# Epoch: 1, Batch: 3200, Loss: 45.11824035644531, Variance: 19910.84375
# Epoch: 1, Batch: 3300, Loss: 48.90838623046875, Variance: 2594.477294921875
# Epoch: 1, Batch: 3400, Loss: 49.61028289794922, Variance: 2110.87939453125
# Epoch: 1, Batch: 3500, Loss: 54.23957061767578, Variance: 9428.0048828125
# Epoch: 1, Batch: 3600, Loss: 41.179725646972656, Variance: 13008.9736328125
# Epoch: 1, Validation loss: 39.17422866821289, Validation ppl: 27.505563735961914
# Wrote model!
# Epoch: 2, Batch: 0, Loss: 49.98176574707031, Variance: 76086.5
# Epoch: 2, Batch: 100, Loss: 48.614105224609375, Variance: 9382.77734375

# %%
for ix,batch in enumerate(train_iter):
    src = batch.src.values.transpose(0,1)
    src = reverse_sequence(src)
    trg = batch.trg.values.transpose(0,1)
    break

h0=None
context, hidden_s2c = seq2context(src,h0)
output, hidden_lm = context2trg(trg[:,:-1],hidden_s2c)


print([EN.vocab.itos[i] for i in torch.argmax(lsm(output),2)[3,:]])
print([EN.vocab.itos[i] for i in trg[3,:]])
# Out:
# ['transfer', 'effective', 'formula', 'collide', 'open', 'breathes', 'demanding', 'Also', 'vanished', 'party', 'condom', 'Things', 'daf-2', 'formula', 'party', 'James', 'party', 'outsiders', 'Bonnet', 'party', 'averse']
# ['<s>', 'We', 'also', 'use', '[', 'an', ']', 'electronic', 'medical', 'record', 'system', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']

# %%
#word_input, last_context, last_hidden, encoder_outputs

encoder_outputs, encoder_hidden = seq2context(src)
encoder_outputs = encoder_outputs[0,:,:]
word_input = torch.tensor([DE.vocab.stoi['<s>']], device='cuda')
last_context = torch.zeros([1, context_size], device='cuda') # 1 x 500
last_hidden = encoder_hidden
last_hidden = tuple([last_hidden[0][:,0,:].view(2,1,500).contiguous(),last_hidden[1][:,0,:].view(2,1,500).contiguous()])
word_embedded = context2trg.emb(word_input).view(1, 1, -1) # 1 x 1 x 500
rnn_input = torch.cat((word_embedded, last_context.unsqueeze(0)), 2) # 1 x 1 x 1000
rnn_output, hidden = attn_context2trg.rnn(rnn_input, last_hidden)

# %%
def attn_dot(rnn_output,encoder_outputs):
    return F.softmax(torch.matmul(rnn_output.squeeze(0),encoder_outputs.transpose(0,1)).squeeze(),dim=0).unsqueeze(0).unsqueeze(0)

# %%
attn_weights = attn_dot(rnn_output,encoder_outputs)
context = attn_weights.bmm(encoder_outputs.unsqueeze(1).transpose(0, 1))
rnn_output = rnn_output.squeeze(0)
context = context.squeeze(1)
output = F.log_softmax(attn_context2trg.lnr(torch.cat((rnn_output, context), 1)),0)

# %%
encoder_outputs, encoder_hidden = seq2context(src)
#encoder_outputs = encoder_outputs[0,:,:]
word_input = torch.tensor([DE.vocab.stoi['<s>']], device='cuda')
last_context = torch.zeros(1, context_size, device='cuda') # 1 x 500
last_hidden = encoder_hidden
#last_hidden = tuple([last_hidden[0][:,0,:].view(2,1,500).contiguous(),last_hidden[1][:,0,:].view(2,1,500).contiguous()])

# %%
decoder_output, decoder_context, decoder_hidden, decoder_attention = attn_context2trg(word_input, last_context, last_hidden, encoder_outputs)

# %%
 decoder_context.shape #decoder_hidden.shape
# Out:
# torch.Size([1, 500])

# %%
word_input = trg[1,1]
decoder_output, decoder_context, decoder_hidden, decoder_attention = attn_context2trg(word_input, decoder_context, decoder_hidden, encoder_outputs)
# Out:
# torch.Size([1, 1, 1000])

# %%
def compare_sentence(trg,ix=32):
    outputs = []
    for j in range(trg.shape[1] - 1):
# Out:
# torch.Size([1, 1, 1000])

# %%
# Out:
# Epoch: 2, Batch: 0, Loss: 161.0377197265625
# ['Solar', 'the', 'we', 'we', 'slow', 'for', 'body', 'like', 'we', 'for', '<pad>', 'get', 'structures', 'the', 'incredible', '<pad>', '<pad>', 'times', '<pad>', 'the', 'off']
# ['<s>', 'It', 'looks', 'like', 'it', "'s", 'kind', 'of', 'been', 'there', ',', 'and', 'then', 'crashed', 'all', 'these', 'simpler', 'forms', 'into', 'it', '.', '</s>']
# Epoch: 2, Batch: 100, Loss: 195.60531616210938
# ['To', 'I', 'be', 'comes', '?', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Just', 'does', "n't", 'make', 'sense', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 200, Loss: 258.91851806640625
# ['It', 'car', 'will', 'things', 'of', '<pad>', 'about', '<pad>', 'of', '<pad>', '?', 'book', '.', 'U', '.', 'enhance', '<pad>', '<pad>', '.', '<pad>', '.']
# ['<s>', 'So', 'the', 'People', "'s", 'Building', ',', 'as', 'we', 'called', 'it', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 300, Loss: 234.93382263183594
# ['Finally', 'HG', 'context', 'pools', 'nuclear', 'War', '<pad>', ',', 'body', 'excerpt', '<pad>', 'roll', 'everyone', 'cardboard', 'pesticides', ',', '1986', '<pad>', 'Stanley', '<pad>', 'disgusting']
# ['<s>', 'They', 'are', 'expected', 'to', 'bear', 'the', 'burden', 'of', 'costs', 'in', 'married', 'life', ',', 'but', 'they', 'ca', "n't", 'find', 'jobs', '.', '</s>']
# Epoch: 2, Batch: 400, Loss: 233.083251953125
# ['rhetoric', 'challenged', '70', '<pad>', 'solution', '<pad>', '<pad>', 'be', '<pad>', '<pad>', '</s>', '<pad>', '<pad>', 'okay', '<pad>', 'ages', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'I', 'said', ',', '"', 'Look', ',', 'it', "'s", ',', 'after', 'all', ',', 'two', 'dollars', '.', 'Take', 'it', 'home', '.', '"', '</s>']
# Epoch: 2, Batch: 500, Loss: 324.41217041015625
# ['They', 'I', 'ears', 'opportunity', 'for', 'read', '<pad>', 'equal', '<pad>', '<pad>', '<pad>', 'complex', '<pad>', '<pad>', '<pad>', '<pad>', 'certainly', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'These', 'are', 'the', 'models', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 600, Loss: 624.012451171875
# ['But', 'Pope', 'in', 'at', 'as', '<pad>', '-', 'die', 'World', 'Mr.', 'fantasy', 'month', 'decided', 'and', 'die', '<pad>', 'but', 'measured', '<pad>', 'die', '<pad>']
# ['<s>', 'There', "'s", 'something', 'very', 'peculiar', 'about', 'Venice', ',', 'that', 'its', 'administration', 'has', 'been', 'very', ',', 'very', 'bureaucratic', '.', '</s>', '<pad>', '<pad>']
# Epoch: 2, Batch: 700, Loss: 350.88470458984375
# ['The', '3D', 'sooner', 'the', 'I', '"', 'the', 'first', 'film', 'done', 'this', 'the', 'used', 'him', 'prices', 'children', 'devices', 'problems', 'despite', 'prices', 'I']
# ['<s>', 'So', 'I', 'was', 'at', 'my', 'minimum', 'altitude', 'in', 'that', 'vector', '--', 'fast', '--', 'so', 'I', 'pulled', 'that', '.', '</s>', '<pad>', '<pad>']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-157-8a006e589129> in <module>()
# ----> 1 attn_training_loop(e=2)
#
# <ipython-input-154-497d3a69be54> in attn_training_loop(e)
#      18             for j in range(trg.shape[1] - 1):
#      19                 word_input = trg[:,j]
# ---> 20                 decoder_output, decoder_context, decoder_hidden, decoder_attention = attn_context2trg(word_input, decoder_context, decoder_hidden, encoder_outputs)
#      21                 #print(decoder_output.shape, trg[i,j+1].view(-1).shape)
#      22                 loss += criterion_train(decoder_output, trg[:,j+1])
#
# /opt/anaconda/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     477             result = self._slow_forward(*input, **kwargs)
#     478         else:
# --> 479             result = self.forward(*input, **kwargs)
#     480         for hook in self._forward_hooks.values():
#     481             hook_result = hook(self, input, result)
#
# <ipython-input-133-259b96fc509a> in forward(self, word_input, last_context, last_hidden, encoder_outputs)
#      16         word_embedded = self.emb(word_input)
#      17         rnn_input = torch.cat([word_embedded, last_context], 1).unsqueeze(1) # batch x 1 x hiddenx2
# ---> 18         rnn_output, hidden = attn_context2trg.rnn(rnn_input, last_hidden)
#      19         attn_weights = rnn_output.bmm(encoder_outputs.transpose(1,2))# batch x src_seqlen x 1
#      20         context = attn_weights.bmm(encoder_outputs)
#
# /opt/anaconda/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     477             result = self._slow_forward(*input, **kwargs)
#     478         else:
# --> 479             result = self.forward(*input, **kwargs)
#     480         for hook in self._forward_hooks.values():
#     481             hook_result = hook(self, input, result)
#
# /opt/anaconda/anaconda3/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     177         if batch_sizes is None:
#     178             result = _impl(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 179                            self.dropout, self.training, self.bidirectional, self.batch_first)
#     180         else:
#     181             result = _impl(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# KeyboardInterrupt:

# %%
class attn_RNNet(torch.nn.Module):

    def __init__(self, input_size, hidden_size, num_layers, dropout=0.5, weight_tie=False, weight_init=0.05):
        super(attn_RNNet, self).__init__()
        self.emb = torch.nn.Sequential(torch.nn.Embedding(input_size, hidden_size), torch.nn.Dropout(dropout))
        self.rnn = torch.nn.LSTM(input_size=2*hidden_size, hidden_size=hidden_size, num_layers=num_layers, bias=True, batch_first=True, dropout=dropout)
        self.lnr = torch.nn.Sequential(torch.nn.Dropout(dropout), torch.nn.Linear(2*hidden_size, input_size))
    
        for f in self.parameters():
            torch.nn.init.uniform_(f, a=-weight_init, b=weight_init)
      
    def attn_dot(self,rnn_output,encoder_outputs):
        return F.softmax(torch.matmul(rnn_output.squeeze(0),encoder_outputs.transpose(0,1)).squeeze(),dim=0).unsqueeze(0).unsqueeze(0)

    def forward(self, word_input, last_context, last_hidden, encoder_outputs):
        word_embedded = self.emb(word_input).view(1, 1, -1) # batch x 1 x hidden
        rnn_input = torch.cat((word_embedded, last_context.unsqueeze(0)), 2) # batch x 1 x hiddenx2
        rnn_output, hidden = self.rnn(rnn_input, last_hidden) # batch x 1 x hidden
        attn_weights = self.attn_dot(rnn_output,encoder_outputs) # encoder_outputs: batch x src_seqlen x hidden # batch x src_seqlen x 1
        context = attn_weights.bmm(encoder_outputs.unsqueeze(1).transpose(0, 1)) # encoder_outputs: 1 x batch x src_seqlen x hidden # batch x hidden
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        output = self.lnr(torch.cat((rnn_output, context), 1)) # cat: batch x hiddenx2 # batch x vocab
        # prediction, last_context, last_hidden, weights for vis
        return output, context, hidden, attn_weights

# %%
class attn_RNNet_batched(torch.nn.Module):

    def __init__(self, input_size, hidden_size, num_layers, dropout=0.5, weight_init=0.05):
        super(attn_RNNet_batched, self).__init__()
        self.emb = torch.nn.Sequential(torch.nn.Embedding(input_size, hidden_size), torch.nn.Dropout(dropout))
        self.rnn = torch.nn.LSTM(input_size=2*hidden_size, hidden_size=hidden_size, num_layers=num_layers, bias=True, batch_first=True, dropout=dropout)
        self.lnr = torch.nn.Sequential(torch.nn.Dropout(dropout), torch.nn.Linear(2*hidden_size, input_size))
    
        for f in self.parameters():
            torch.nn.init.uniform_(f, a=-weight_init, b=weight_init)
      
    def attn_dot(self,rnn_output,encoder_outputs):
        return F.softmax(torch.matmul(rnn_output.squeeze(0),encoder_outputs.transpose(0,1)).squeeze(),dim=0).unsqueeze(0).unsqueeze(0)

    def forward(self, word_input, last_context, last_hidden, encoder_outputs):
        word_embedded = self.emb(word_input)
        rnn_input = torch.cat([word_embedded, last_context], 1).unsqueeze(1) # batch x 1 x hiddenx2
        rnn_output, hidden = self.rnn(rnn_input, last_hidden)
        attn_weights = rnn_output.bmm(encoder_outputs.transpose(1,2))# batch x src_seqlen x 1
        context = attn_weights.bmm(encoder_outputs)
        rnn_output = rnn_output.squeeze(1)
        context = context.squeeze(1)
        output = self.lnr(torch.cat((rnn_output, context), 1))
        # prediction, last_context, last_hidden, weights for vis
        return output, context, hidden, attn_weights

# %%
context_size = 500
num_layers = 2
attn_context2trg = attn_RNNet_batched(input_size=len(EN.vocab),hidden_size=context_size,num_layers=num_layers)
attn_context2trg = attn_context2trg.cuda()
attn_context2trg_optimizer = torch.optim.Adam(attn_context2trg.parameters(), lr=1e-3)

seq2context = SequenceModel(len(DE.vocab),context_size,num_layers=num_layers)
seq2context_optimizer = torch.optim.Adam(seq2context.parameters(), lr=1e-3)
seq2context = seq2context.cuda()

# %%
criterion_train = nn.CrossEntropyLoss(reduction='sum')
lsm2 = nn.LogSoftmax(dim=1)
def attn_training_loop(e=0):
    for ix,batch in enumerate(train_iter):
        src = batch.src.values.transpose(0,1)
        src = reverse_sequence(src)
        trg = batch.trg.values.transpose(0,1)
        if trg.shape[0] == BATCH_SIZE:
        
            seq2context_optimizer.zero_grad()
            attn_context2trg_optimizer.zero_grad()
        
            encoder_outputs, encoder_hidden = seq2context(src)
            loss = 0
            decoder_context = torch.zeros(BATCH_SIZE, context_size, device='cuda') # 32 x 500
            decoder_hidden = encoder_hidden
            sentence = []
            for j in range(trg.shape[1] - 1):
                word_input = trg[:,j]
                decoder_output, decoder_context, decoder_hidden, decoder_attention = attn_context2trg(word_input, decoder_context, decoder_hidden, encoder_outputs)
                #print(decoder_output.shape, trg[i,j+1].view(-1).shape)
                loss += criterion_train(decoder_output, trg[:,j+1])
                
                if np.mod(ix,100) == 0:
                    sentence.extend([torch.argmax(decoder_output[0,:],dim=0)])
                
            loss.backward()
            seq2context_optimizer.step()
            attn_context2trg_optimizer.step()
        
            if np.mod(ix,100) == 0:
                print('Epoch: {}, Batch: {}, Loss: {}'.format(e, ix, loss.cpu().detach()/BATCH_SIZE))
                print([EN.vocab.itos[i] for i in sentence])
                print([EN.vocab.itos[i] for i in trg[0,:]])

# %%
for e in range(2,8):
    attn_training_loop(e)
# Out:
# Epoch: 2, Batch: 0, Loss: 42.48237228393555
# ['Child', ':', '<unk>', '!', 'Look', 'at', 'the', '!', '!', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Child', ':', 'Whoa', '!', 'Look', 'at', 'that', 'snake', '!', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 100, Loss: 30.164155960083008
# ['What', 'do', 'we', 'do', 'with', 'the', '<unk>', ',', ',', 'do', 'longer', 'have', 'on', 'lot', 'on', 'this', 'planet', '?', '</s>', '<pad>', '<pad>']
# ['<s>', 'What', 'do', 'we', 'do', 'with', 'displaced', 'fellow', '<unk>', 'who', 'no', 'longer', 'have', 'a', 'home', 'on', 'the', 'planet', '?', '</s>', '<pad>', '<pad>']
# Epoch: 2, Batch: 200, Loss: 30.560657501220703
# ['Can', 'imagine', 'imagine', 'that', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Can', 'you', 'imagine', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 300, Loss: 35.38581085205078
# ['I', "'m", 'not', 'saying', 'that', 'should', "n't", 'do', 'rid', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'I', "'m", 'not', 'saying', 'we', 'should', "n't", 'cut', 'emissions', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 400, Loss: 36.71293258666992
# ['I', 'I', 'want', 'want', 'to', 'show', 'you', 'that', 'I', "'m", 'not', 'just', '<unk>', ',', 'but', 'it', 'also', 'want', '.', '</s>', '<pad>']
# ['<s>', 'And', 'I', 'just', 'want', 'to', 'show', 'you', 'that', 'I', "'m", 'not', 'just', '<unk>', ',', 'but', 'I', 'also', 'practice', '.', '</s>', '<pad>']
# Epoch: 2, Batch: 500, Loss: 31.982515335083008
# ['I', 'want', 'to', 'share', 'you', 'picture', 'of', 'my', 'friend', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'I', 'want', 'to', 'show', 'a', 'picture', 'of', 'my', 'friend', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 600, Loss: 31.933664321899414
# ['We', 'know', 'about', 'from', 'from', 'a', 'on', 'on', 'lot', 'at', 'on', 'the', 'planet', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'We', 'know', 'hydrogen', 'sulfide', 'is', '<unk>', '<unk>', 'a', 'few', 'places', 'on', 'the', 'planet', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 700, Loss: 41.575504302978516
# ['But', 'we', 'is', 'what', 'global', 'phenomenon', 'that', 'that', 'know', 'that', 'is', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'But', 'this', 'is', 'a', 'global', 'phenomenon', ',', 'we', 'know', 'that', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 800, Loss: 29.278276443481445
# ['There', 'are', 'lots', 'pictures', 'of', '<unk>', '<unk>', '.', "'s", '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'There', 'are', 'many', 'photos', 'of', 'Mr.', '<unk>', 'that', 'exist', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 900, Loss: 32.607173919677734
# ['You', 'can', 'see', 'it', 'in', 'the', 'life', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'You', 'can', 'see', 'it', 'in', 'daily', 'life', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 1000, Loss: 33.454219818115234
# ['She', 'sat', 'there', 'in', 'a', '<unk>', 'of', '<unk>', '.', 'in', 'or', ',', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'She', 'sat', 'there', 'in', 'a', 'sort', 'of', 'hand', '-', '<unk>', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 1100, Loss: 42.18102264404297
# ['I', 'I', 'thought', 'thought', 'that', 'would', 'going', 'to', 'be', 'a', '<unk>', '<unk>', '<unk>', '.', '<unk>', '.', '.', '.', '</s>', '<pad>', '<pad>']
# ['<s>', 'And', 'I', 'really', 'thought', 'this', 'was', 'going', 'to', 'be', 'a', 'straight', '-', 'to', '-', 'PBS', 'charitable', 'initiative', '.', '</s>', '<pad>', '<pad>']
# Epoch: 2, Batch: 1200, Loss: 37.141197204589844
# ['I', '<unk>', 'go', 'back', 'a', 'little', 'bit', 'of', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'I', "'ll", 'zoom', 'in', 'a', 'little', 'bit', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 1300, Loss: 33.95014190673828
# ['If', 'you', 'put', 'two', 'two', 'in', 'two', 'organism', ',', 'it', "'s", 'not', 'a', 'accident', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'When', 'you', 'have', 'two', 'outliers', 'in', 'one', 'organism', ',', 'it', "'s", 'not', 'a', 'coincidence', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 1400, Loss: 37.38433074951172
# ['And', 'so', 'I', 'I', "'m", ',', ',', 'I', 'call', '.', '<unk>', '<unk>', '.', '</s>', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'so', ',', 'I', 'have', 'here', 'what', 'we', 'call', 'the', '"', 'paradigms', '.', '"', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 1500, Loss: 33.84907531738281
# ['And', 'they', ',', 'they', "'re", 'not', ',', 'and', 'you', 'only', 'no', 'different', 'different', 'different', 'results', '.', '</s>', '<pad>', '<pad>']
# ['<s>', 'But', 'other', 'times', 'they', "'re", 'not', ',', 'and', 'you', 'have', 'only', 'probabilities', 'for', 'different', 'outcomes', '.', '</s>', '<pad>', '<pad>']
# Epoch: 2, Batch: 1600, Loss: 31.152273178100586
# ['The', 'heart', 'of', 'like', 'like', ',', 'but', 'but', 'is', 'a', 'lot', '<unk>', 'thing', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Their', 'heart', 'was', 'still', 'pounding', ',', 'but', 'this', 'is', 'a', 'much', 'healthier', 'cardiovascular', 'profile', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 1700, Loss: 36.3916130065918
# ['And', 'that', 'that', 'is', 'what', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'partly', 'this', 'is', 'already', 'happening', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 1800, Loss: 41.119232177734375
# ['Let', 'let', "'s", 'try', 'at', 'the', 'this', 'is', 'in', '-', '<unk>', 'in', 'in', 'in', 'the', 'world', 'in', '.', '</s>', '<pad>', '<pad>']
# ['<s>', 'So', 'let', "'s", 'look', 'at', 'how', 'China', 'is', 're', '-', '<unk>', 'that', 'hierarchy', 'in', 'the', 'far', 'East', '.', '</s>', '<pad>', '<pad>']
# Epoch: 2, Batch: 1900, Loss: 36.85460662841797
# ['That', "'s", 'a', 'third', 'third', 'of', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'That', "'s", 'a', 'third', 'side', 'act', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 2000, Loss: 33.40216064453125
# ['We', 'need', 'more', 'science', 'and', 'not', ',', 'science', 'We', 'we', 'need', 'good', 'science', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'We', 'need', 'more', 'science', 'and', 'not', 'less', '.', 'And', 'we', 'need', 'good', 'science', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 2100, Loss: 35.08928680419922
# ['This', 'this', 'is', 'a', 'smaller', '<unk>', 'of', 'a', '<unk>', 'school', 'called', 'which', 'is', 'in', '<unk>', '.', 'England', '.', '</s>', '<pad>']
# ['<s>', 'And', 'this', 'is', 'a', 'little', 'clip', 'from', 'an', 'elementary', 'school', ',', 'which', 'is', 'very', 'common', 'in', 'England', '.', '</s>', '<pad>']
# Epoch: 2, Batch: 2200, Loss: 35.744720458984375
# ['We', 'heard', 'yesterday', 'about', 'the', 'importance', 'of', 'new', 'materials', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'We', 'heard', 'yesterday', 'about', 'the', 'importance', 'of', 'new', 'materials', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 2300, Loss: 34.328792572021484
# ['What', 'what', 'we', 'what', 'we', 'found', 'was', 'completely', 'completely', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'here', ',', 'what', 'we', 'found', 'was', 'completely', 'unexpected', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 2400, Loss: 35.16185760498047
# ['But', 'there', "'s", 'a', 'of', 'things', 'I', 'do', 'been', 'to', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'But', 'there', 'are', 'plenty', 'of', 'things', 'I', 'have', 'trouble', 'understanding', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 2500, Loss: 40.10914993286133
# ['There', 'are', 'some', 'of', 'that', 'you', "'s", 'be', 'you', 'a', 'of', 'of', 'a', 'middle', 'of', 'a', '<unk>', '.', '</s>', '<pad>', '<pad>']
# ['<s>', 'There', 'is', 'some', 'indication', 'that', 'it', 'may', 'buy', 'you', 'some', 'time', 'in', 'the', 'midst', 'of', 'an', 'outbreak', '.', '</s>', '<pad>', '<pad>']
# Epoch: 2, Batch: 2600, Loss: 36.071407318115234
# ['But', 'I', "'ve", 'say', 'that', 'have', 'not', 'not', 'to', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'But', 'I', 'must', 'say', 'they', 'are', 'no', 'longer', 'natural', 'disasters', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 2700, Loss: 35.95868682861328
# ['These', 'things', 'of', 'the', 'things', 'is', 'very', 'very', 'difficult', 'story', '.', 'see', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Making', 'sense', 'of', 'those', 'things', 'is', 'a', 'very', 'difficult', 'thing', 'to', 'do', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 2800, Loss: 30.992761611938477
# ['It', "'s", 'just', 'simple', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'It', "'s", 'just', 'happening', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 2900, Loss: 32.93461608886719
# ['You', ',', 'the', ',', 'see', 'where', 'you', 'was', 'made', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', '<unk>', 'into', 'it', 'and', 'see', 'where', 'it', 'was', 'taken', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 3000, Loss: 43.27320098876953
# ['<unk>', '<unk>', ',', 'he', 'seen', 'in', 'in', 'in', 'the', '<unk>', ',', '<unk>', 'translation', '.', '<unk>', '.', '.', '</s>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'In', '<unk>', 'he', 'was', 'last', 'seen', 'disappearing', 'into', 'the', 'clouds', 'near', 'the', 'summit', 'of', '<unk>', 'Everest', '.', '</s>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 3100, Loss: 37.1220588684082
# ['This', 'comes', 'coming', 'from', 'us', 'and', 'and', 'I', 'think', 'it', 'is', 'going', 'to', 'be', 'revolution', 'revolution', '.', '</s>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'This', 'is', 'coming', 'towards', 'us', ',', 'and', 'I', 'think', 'this', 'is', 'going', 'to', 'be', 'a', 'revolution', '.', '</s>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 3200, Loss: 31.384706497192383
# ['So', 'is', 'how', '<unk>', 'of', 'them', 'you', 'get', 'take', 'take', 'in', '<unk>', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'This', 'is', 'their', 'perception', 'of', 'why', 'you', 'should', "n't", 'mess', 'with', '<unk>', 'Indians', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 3300, Loss: 39.88798904418945
# ['You', 'have', 'got', 'the', 'war', ',', 'and', 'I', 'call', 'it', '"', '"', 'generation', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'They', "'ve", 'stopped', 'the', 'fighting', ',', 'and', 'I', 'call', 'them', 'the', '<unk>', 'generation', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 3400, Loss: 37.77948760986328
# ['This', 'is', 'the', '<unk>', '<unk>', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'This', 'is', 'the', 'amino', 'acid', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 3500, Loss: 35.42962646484375
# ['They', "'re", 'a', '<unk>', ',', ',', '<unk>', ',', '<unk>', '-', 'with', ',', 'the', 'people', '.', '<unk>', '.', '</s>', '<pad>', '<pad>']
# ['<s>', 'They', "'re", 'a', 'cult', 'all', 'their', 'own', ',', 'blood', 'brothers', 'steeped', 'in', 'other', 'people', "'s", 'blood', '.', '</s>', '<pad>', '<pad>']
# Epoch: 2, Batch: 3600, Loss: 27.00701141357422
# ['The', 'in', 'a', 'of', 'in', 'be', '.', 'a', 'world', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Go', 'from', 'one', 'world', 'to', 'another', 'in', 'a', 'second', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 2, Batch: 3700, Loss: 40.87113571166992
# ['<unk>', ':', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', 'to', '<unk>', 'the', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', '<unk>', ':', 'Israeli', 'border', 'police', 'were', 'sent', 'to', '<unk>', 'the', 'crowd', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 0, Loss: 30.118629455566406
# ['He', 'sent', 'have', 'me', 'a', '<unk>', ',', 'he', 'me', 'a', 'about', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'He', 'would', 'send', 'me', 'a', '<unk>', 'and', 'show', 'me', 'something', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 100, Loss: 28.712919235229492
# ['BF', ':', 'Thank', 'you', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'BF', ':', 'Thank', 'you', 'guys', '!', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 200, Loss: 34.92640686035156
# ['So', 'of', 'eyes', ',', 'ladies', 'and', 'gentlemen', ',', 'that', 'was', '1960', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Bear', 'in', 'mind', ',', 'ladies', 'and', '<unk>', ',', 'this', 'was', '1960', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 300, Loss: 33.08658218383789
# ['Many', 'lot', 'of', 'students', 'students', 'go', 'theater', 'the', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'A', 'lot', 'of', 'our', 'students', 'get', 'into', 'theater', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 400, Loss: 28.19732093811035
# ['We', 'want', 'to', 'do', 'like', 'we', 'that', 'this', ',', ',', ',', 'the', 'way', 'of', 'thing', ',', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'We', 'want', 'to', ',', 'and', 'do', ',', '<unk>', 'accounts', 'engaging', 'in', 'that', 'kind', 'of', 'behavior', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 500, Loss: 28.589311599731445
# ['How', 'do', 'you', 'be', 'that', 'that', 'to', 'to', 'be', 'anything', '?', 'you', 'is', 'you', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'How', 'should', 'one', 'live', 'in', 'order', 'not', 'to', 'feel', 'regret', 'when', 'one', 'is', 'dying', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 600, Loss: 28.84320640563965
# ['So', 'that', 'is', 'what', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'So', 'this', 'is', 'true', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 700, Loss: 40.946128845214844
# ['So', 'I', 'proposed', 'to', 'to', 'it', '.', 'Everybody', 'can', 'write', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'So', 'I', 'came', 'up', 'with', 'lists', '.', 'Everyone', 'can', 'write', 'lists', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 800, Loss: 35.10213088989258
# ['In', 'the', '<unk>', ',', 'they', 'go', 'the', 'walls', 'and', '<unk>', 'trees', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'In', 'the', 'lobby', ',', 'they', 'painted', 'the', 'walls', 'and', 'planted', 'trees', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 900, Loss: 31.37110137939453
# ['And', 'have', 'went', 'the', 'sound', 'as', 'make', 'the', 'without', 'of', 'a', 'infrastructure', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'We', 'then', 'take', 'the', 'parks', 'and', 'lay', 'them', 'out', 'as', 'ecological', 'infrastructure', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 1000, Loss: 25.865135192871094
# ['That', "'s", 'why', 'they', 'use', 'them', 'in', 'production', 'of', 'and', 'spend', 'much', 'lot', 'of', 'money', 'to', 'develop', 'them', '.', '</s>']
# ['<s>', 'That', "'s", 'why', 'they', 'use', 'it', 'in', 'production', ',', 'they', 'pay', 'a', 'lot', 'of', 'money', 'to', 'develop', 'it', '.', '</s>']
# Epoch: 3, Batch: 1100, Loss: 31.566974639892578
# ['And', 'the', 'reason', 'is', ',', 'it', 'was', 'already', 'done', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'the', 'reason', 'is', ',', 'it', "'s", 'been', 'done', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 1200, Loss: 37.09458923339844
# ['So', 'what', 'if', 'I', 'mean', 'when', 'I', 'meet', 'a', '<unk>', 'animation', '?', 'right', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'So', 'what', 'do', 'I', 'mean', 'when', 'I', 'say', '"', 'suspended', 'animation', '"', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 1300, Loss: 35.31074142456055
# ['So', ',', 'the', "'s", 'been', 'case', ',', 'it', "'s", 'difficult', ',', 'because', 'it', 'is', 'really', 'difficult', '.', '</s>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'So', 'if', 'that', "'s", 'the', 'case', ',', 'that', "'s", 'difficult', ',', 'because', 'persuasion', 'is', 'really', 'difficult', '.', '</s>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 1400, Loss: 29.3020076751709
# ['I', 'years', 'years', 'years', 'old', '--', 'I', 'I', 'years', 'years', ',', 'was', 'this', '.', 'this', 'material', '.', '</s>', '<pad>', '<pad>']
# ['<s>', 'Remember', 'at', '10', 'years', 'old', '--', 'so', '34', 'years', 'ago', 'I', 'saw', 'opportunity', 'in', 'this', 'stuff', '.', '</s>', '<pad>', '<pad>']
# Epoch: 3, Batch: 1500, Loss: 34.513343811035156
# ['But', 'actually', 'fact', ',', 'these', 'is', 'of', 'a', 'is', 'a', 'a', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'But', 'in', 'fact', ',', 'this', 'metaphor', 'of', 'decline', 'is', 'often', 'very', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 1600, Loss: 35.664794921875
# ['It', 'it', 'was', 'from', 'from', 'from', ',', 'by', 'the', '<unk>', '<unk>', '<unk>', 'of', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'it', "'s", 'based', ',', 'actually', ',', 'on', 'a', 'more', 'elevated', 'piece', 'of', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 1700, Loss: 34.513431549072266
# ['You', 'do', 'to', 'people', 'to', 'learn', 'the', 'learn', '.', 'people', '.', 'are', 'are', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'You', 'need', 'the', 'time', 'to', 'get', 'to', 'know', 'the', 'people', 'that', 'you', "'re", 'serving', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 1800, Loss: 29.024133682250977
# ['I', 'I', 'I', "'m", 'this', 'device', '.', 'now', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Now', ',', 'I', 'have', 'this', 'device', 'on', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 1900, Loss: 32.60281753540039
# ['Now', ',', 'I', 'I', 'the', ',', 'I', 'follow', 'the', 'queen', 'because', 'it', "'s", 'funny', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Well', ',', 'first', 'of', 'all', ',', 'I', 'blame', 'the', 'Queen', 'because', 'it', "'s", 'funny', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 2000, Loss: 37.86307907104492
# ['From', 'can', 'see', ',', ',', ',', '.', 'it', 'there', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'You', 'can', 'see', 'it', 'even', 'better', 'from', 'down', 'on', 'top', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 2100, Loss: 31.177560806274414
# ['So', 'is', 'extremely', ',', 'hard', 'feels', ',', 'important', '.', 'That', 'this', "'s", 'cool', 'of', 'cool', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'This', 'is', 'heavy', 'so', 'it', 'feels', 'more', 'important', '.', 'So', 'it', "'s", 'kind', 'of', 'cool', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 2200, Loss: 30.561887741088867
# ['By', 'this', ',', 'transparency', 'and', '<unk>', 'to', 'lot', 'job', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Make', 'clarity', ',', 'transparency', 'and', 'simplicity', 'a', 'national', 'priority', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 2300, Loss: 29.00699234008789
# ['Thank', 'you', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Thank', 'you', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 2400, Loss: 36.602848052978516
# ['And', 'then', 'I', 'took', 'the', 'pieces', 'that', 'I', 'took', 'to', 'and', 'and', 'then', 'down', 'down', 'the', 'bottom', '.', '</s>', '<pad>', '<pad>']
# ['<s>', 'But', 'then', 'I', 'took', 'the', 'pieces', 'that', 'I', 'had', 'taken', 'off', 'and', 'put', 'them', 'at', 'the', 'bottom', '.', '</s>', '<pad>', '<pad>']
# Epoch: 3, Batch: 2500, Loss: 34.91507339477539
# ['So', ',', 'went', 'in', 'in', 'I', 'night', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'So', 'I', 'went', 'back', 'that', 'very', 'summer', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 2600, Loss: 28.77419090270996
# ['Some', 'are', 'actually', '<unk>', 'a', '<unk>', 'of', 'the', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Some', 'are', 'actually', 'on', 'the', '<unk>', 'of', 'extinction', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 2700, Loss: 28.75575828552246
# ['It', "'s", 'us', 'see', 'see', 'differently', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'It', 'allows', 'us', 'to', 'see', 'different', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 2800, Loss: 29.434473037719727
# ['We', 'have', 'to', 'have', 'a', 'new', 'paradigm', 'of', '<unk>', 'and', 'respect', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'We', 'need', 'to', 'get', 'the', 'new', 'paradigm', 'of', '<unk>', 'and', 'respect', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 2900, Loss: 35.623172760009766
# ['We', "'re", 'building', 'our', 'way', 'into', 'a', 'new', 'economy', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'We', 'are', 'growing', 'our', 'way', 'into', 'a', 'new', 'economy', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 3000, Loss: 32.37638854980469
# ['OK', ',', 'it', "'s", 'time', 'to', 'show', 'them', 'of', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'OK', ',', 'it', "'s", 'time', 'to', 'kick', 'some', 'ass', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 3100, Loss: 29.87431526184082
# ['And', 'after', 'after', 'few', ',', 'the', ',', ',', ',', ',', '"', 'said', ',', '"', 'no', 'paper', '?', '"', '</s>', '<pad>', '<pad>']
# ['<s>', 'And', 'after', 'a', 'second', 'or', 'two', ',', 'carefully', '<unk>', ',', 'she', 'said', ',', '"', 'No', 'paper', '?', '"', '</s>', '<pad>', '<pad>']
# Epoch: 3, Batch: 3200, Loss: 37.181514739990234
# ['One', '<unk>', '<unk>', '<unk>', 'has', 'work', 'up', 'in', '<unk>', '.', 'because', 'they', 'do', "n't", '.', 'it', '.', '</s>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'A', 'functioning', 'executive', 'that', 'will', 'translate', 'will', 'into', 'action', ',', 'because', 'we', 'do', "n't", 'have', 'it', '.', '</s>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 3300, Loss: 30.4371395111084
# ['This', "'s", 'called', '"', '<unk>', '.', '"', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'That', "'s", 'called', '"', '<unk>', '.', '"', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 3400, Loss: 35.12836456298828
# ['And', 'that', 'is', 'the', 'great', 'great', 'of', 'science', 'science', 'the', 'security', 'of', 'experiments', 'experiments', '.', 'experiments', '.', '</s>', '<pad>', '<pad>']
# ['<s>', 'And', 'this', 'is', 'the', 'great', 'pleasure', 'of', 'science', ':', 'the', 'defeat', 'of', 'our', 'intuition', 'through', 'experimentation', '.', '</s>', '<pad>', '<pad>']
# Epoch: 3, Batch: 3500, Loss: 34.881553649902344
# ['The', 'answer', 'is', 'that', 'that', 'average', ',', 'that', 'answer', 'exciting', 'teachers', 'are', '.', 'system', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'The', 'answer', 'is', ',', 'on', 'average', ',', 'the', 'slightly', 'better', 'teachers', 'leave', 'the', 'system', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 3, Batch: 3600, Loss: 29.95343017578125
# ['To', 'have', 'a', 'brain', 'brain', 'those', 'size', 'to', 'you', 'need', 'a', 'have', 'a', '<unk>', 'of', 'high', '.', '.', '.', '</s>', '<pad>']
# ['<s>', 'To', 'have', 'a', 'brain', 'of', 'that', 'size', ',', 'you', 'need', 'to', 'have', 'a', 'source', 'of', '<unk>', '<unk>', 'energy', '.', '</s>', '<pad>']
# Epoch: 3, Batch: 3700, Loss: 25.016408920288086
# ['This', 'that', 'are', 'these', '<unk>', 'in', 'blue', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'and', 'those', 'are', 'the', 'areas', 'in', 'blue', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 0, Loss: 31.511667251586914
# ['Or', 'at', 'like', 'own', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'or', 'even', 'your', 'own', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 100, Loss: 28.431636810302734
# ['Most', '<unk>', '<unk>', 'use', 'the', '<unk>', ',', ',', 'which', 'is', 'using', '<unk>', '<unk>', ',', 'use', 'words', '.', '</s>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Most', 'ancient', 'scripts', 'use', 'the', '<unk>', 'principle', ',', 'which', 'is', ',', 'using', 'pictures', 'to', 'represent', 'words', '.', '</s>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 200, Loss: 31.983911514282227
# ['There', 'was', 'a', '<unk>', '-', '<unk>', ',', 'a', 'large', '<unk>', '-', '<unk>', ',', 'the', 'the', ',', '<unk>', '.', '</s>', '<pad>', '<pad>']
# ['<s>', 'There', 'was', 'a', 'co', '-', 'creation', ',', 'a', 'huge', 'co', '-', 'creation', ',', 'with', '<unk>', 'and', '<unk>', '.', '</s>', '<pad>', '<pad>']
# Epoch: 4, Batch: 300, Loss: 32.78689956665039
# ['India', 'did', 'has', 'a', 'good', '-', 'before', '<unk>', 'before', 'the', 'China', 'China', 'China', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'India', 'still', 'has', 'a', 'long', 'way', 'to', 'go', 'to', 'catch', 'up', 'with', 'China', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 400, Loss: 28.59856414794922
# ['He', 'actually', 'even', 'the', 'bones', 'of', 'the', 'human', 'body', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'He', 'even', 'photographed', 'the', 'bones', 'of', 'the', 'human', 'body', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 500, Loss: 36.9764404296875
# ['So', 'we', 'we', "'re", 'is', 'we', 'do', 'a', 'to', 'on', 'your', 'computer', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'So', 'what', 'we', 'do', 'is', 'we', 'generate', 'encryption', 'keys', 'on', 'your', 'computer', ',', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 600, Loss: 31.914546966552734
# ['And', 'two', 'were', 'two', 'journalists', ',', ',', 'it', 'was', 'not', 'a', ',', 'it', "'s", 'her', '<unk>', '.', 'old', '.', '.', '</s>']
# ['<s>', 'And', 'there', 'was', 'two', 'journalists', 'involved', 'that', 'clearly', 'were', "n't", '<unk>', 'because', 'that', "'s", 'their', 'full', '-', 'time', 'job', '.', '</s>']
# Epoch: 4, Batch: 700, Loss: 31.82148551940918
# ['This', 'this', 'scenario', 'is', 'predictions', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'So', 'this', 'scenario', 'makes', 'predictions', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 800, Loss: 27.69880485534668
# ['So', '<unk>', "'s", 'what', ',', 'I', 'do', 'going', 'at', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'that', "'s", 'really', 'what', 'I', "'m", 'looking', 'for', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 900, Loss: 30.83104705810547
# ['<unk>', 'next', '<unk>', 'shapes', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', '<unk>', 'against', 'sharp', 'things', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 1000, Loss: 24.08753204345703
# ['And', 'that', "'s", 'going', 'first', 'product', 'that', 'we', 'will', 'going', 'to', 'get', '.', '.', 'second', 'of', 'product', '.', '</s>', '<pad>']
# ['<s>', 'And', 'that', "'s", 'our', 'first', 'product', 'that', 'we', "'re", 'going', 'to', 'release', 'in', 'a', 'couple', 'of', 'weeks', '.', '</s>', '<pad>']
# Epoch: 4, Batch: 1100, Loss: 28.795141220092773
# ['They', "'re", 'all', 'members', 'tribes', 'in', 'tribes', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'You', "'re", 'all', 'a', 'member', 'of', 'tribes', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 1200, Loss: 35.05225372314453
# ['Yet', ',', 'both', 'are', 'states', 'have', 'both', '<unk>', '<unk>', '.', '.', 'that', 'is', 'the', '<unk>', '.', 'the', '.', '.', '</s>', '<pad>']
# ['<s>', 'However', ',', 'these', 'two', 'countries', 'have', 'the', 'identical', '<unk>', '<unk>', ',', 'which', 'is', 'a', 'measure', 'of', 'income', 'equality', '.', '</s>', '<pad>']
# Epoch: 4, Batch: 1300, Loss: 28.294179916381836
# ['They', "'s", '<unk>', '.', 'They', 'could', "n't", 'understand', 'why', 'I', 'was', 'so', 'miserable', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'She', 'was', 'smiling', '.', 'She', 'did', 'not', 'understand', 'why', 'I', 'was', 'so', 'worried', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 1400, Loss: 31.47518539428711
# ['You', 'you', "'re", 'poor', ',', 'corruption', 'has', 'no', 'a', 'difference', 'difference', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'When', 'you', "'re", 'poor', ',', 'corruption', 'is', 'not', 'your', 'biggest', 'priority', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 1500, Loss: 27.314430236816406
# ['My', 'goal', 'is', 'to', 'be', 'to', 'to', ',', ',', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'My', 'goal', 'is', 'to', 'come', 'up', 'here', 'independently', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 1600, Loss: 38.428524017333984
# ['She', '<unk>', 'going', 'to', 'be', 'their', 'water', 'the', 'water', 'and', 'and', 'and', 'and', 'forth', '.', '</s>', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'She', "'s", 'going', 'to', 'spend', 'most', 'of', 'her', 'life', '<unk>', 'water', 'back', 'and', 'forth', '.', '"', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 1700, Loss: 31.88353729248047
# ['I', "'m", 'to', 'work', 'you', 'why', 'work', ',', 'what', 'know', 'what', 'I', 'am', 'and', 'why', 'why', 'I', "'m", 'here', '.', '</s>']
# ['<s>', 'I', 'want', 'to', 'show', 'you', 'my', 'work', 'so', 'you', 'know', 'what', 'I', 'am', 'doing', 'and', 'why', 'I', 'am', 'here', '.', '</s>']
# Epoch: 4, Batch: 1800, Loss: 24.965686798095703
# ['So', ',', 'the', "'ve", 'to', 'the', 'to', '<unk>', '<unk>', '<unk>', "'s", '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Well', ',', 'we', 'went', 'to', 'Brazil', 'to', 'meet', 'Dr.', 'Jose', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 1900, Loss: 36.682823181152344
# ['I', 'mean', ',', 'if', 'all', 'of', 'were', 'cows', ',', 'would', 'be', ',', '.', 'that', '.', 'which', ',', '</s>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'I', 'mean', ',', 'if', 'all', 'cows', 'were', 'purple', 'you', "'d", 'get', 'bored', 'with', 'those', ',', 'too', '.', '</s>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 2000, Loss: 31.965097427368164
# ['This', 'this', 'is', 'a', 'guy', 'that', '<unk>', '<unk>', '<unk>', '.', 'and', 'is', 'a', 'the', 'see', 'at', '.', '.', '.', '</s>']
# ['<s>', 'And', 'this', 'is', 'a', 'guy', 'from', '<unk>', 'Lake', 'City', ',', 'this', 'is', 'what', 'they', 'look', 'like', 'out', 'there', '.', '</s>']
# Epoch: 4, Batch: 2100, Loss: 31.126502990722656
# ['It', 'it', 'going', 'to', 'look', 'like', 'this', 'as', '<unk>', '<unk>', 'a', '-', '<unk>', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Is', 'it', 'going', 'to', 'look', 'like', 'this', 'beautiful', 'estate', 'is', 'sub', '-', 'divided', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 2200, Loss: 31.798084259033203
# ['So', 'so', 'I', 'said', ',', '"', 'Are', 'you', 'just', 'just', 'in', 'this', 'office', '?', '"', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'so', 'I', 'said', ',', '"', 'Did', 'you', 'just', 'move', 'into', 'this', 'office', '?', '"', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 2300, Loss: 36.66518783569336
# ['No', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'No', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 2400, Loss: 31.992145538330078
# ['And', 'they', 'allows', 'us', 'to', 'reality', 'in', 'in', 'in', 'into', 'different', 'ways', '--', 'like', 'like', 'a', 'coral', '.', '</s>', '<pad>', '<pad>']
# ['<s>', 'And', 'it', 'tells', 'us', 'our', 'reality', 'is', '<unk>', 'branching', 'into', 'different', 'possibilities', ',', 'just', 'like', 'a', 'coral', '.', '</s>', '<pad>', '<pad>']
# Epoch: 4, Batch: 2500, Loss: 33.526954650878906
# ['Thank', 'you', 'very', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Thank', 'you', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 2600, Loss: 35.1256217956543
# ['He', "'s", 'be', 'the', '<unk>', 'and', 'and', 'and', 'the', 'the', '<unk>', 'of', 'the', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'He', 'will', 'protect', 'his', 'own', 'people', ',', 'and', 'answer', 'the', 'prayers', 'of', 'the', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 2700, Loss: 32.481204986572266
# ['In', 'the', 'the', 'the', ',', '<unk>', 'has', '<unk>', 'be', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Then', ',', 'with', '<unk>', ',', 'everything', 'started', 'to', 'become', 'centralized', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 2800, Loss: 26.166555404663086
# ['So', ',', 'my', 'wish', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'So', ',', 'my', 'wish', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 2900, Loss: 37.32612991333008
# ['And', "'s", 'how', 'I', 'I', 'the', 'years', ',', ',', '</s>', 'did', '<unk>', 'up', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'That', "'s", 'how', ',', 'at', '17', 'years', 'old', ',', 'I', 'started', 'pasting', 'them', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 3000, Loss: 38.150108337402344
# ['Do', 'you', 'know', 'it', 'it', '<unk>', '?', '<unk>', '?', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Do', 'you', 'know', 'about', 'the', 'parent', '-', 'teacher', 'conference', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 3100, Loss: 27.947603225708008
# ['He', '<unk>', 'the', '<unk>', 'on', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'He', 'built', 'the', 'capital', 'over', 'there', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 3200, Loss: 20.988300323486328
# ['At', 'found', ',', 'was', 'very', 'very', 'bit', '.', 'all', 'time', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'I', 'thought', 'this', 'was', 'a', 'little', 'strange', 'at', 'the', 'time', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 3300, Loss: 29.91533660888672
# ['That', 'can', 'be', 'able', '.', '.', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'This', 'can', 'be', 'integrated', 'with', 'decisions', 'support', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 3400, Loss: 31.14093017578125
# ['<unk>', 'fact', '<unk>', ',', '<unk>', '<unk>', ',', 'the', '<unk>', 'as', 'the', '<unk>', 'of', 'hope', 'about', 'the', '.', '</s>', '</s>', '<pad>', '<pad>']
# ['<s>', 'In', 'the', 'words', 'of', 'Samuel', 'Johnson', ',', '"', '<unk>', 'is', 'the', 'triumph', 'of', 'hope', 'over', 'experience', '.', '"', '</s>', '<pad>', '<pad>']
# Epoch: 4, Batch: 3500, Loss: 29.63248062133789
# ['CA', ':', 'So', 'on', 'the', 'road', ',', 'are', '<unk>', '<unk>', '?', '</s>', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'CA', ':', 'So', 'on', 'the', 'streets', ',', 'are', 'film', '<unk>', '...', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 4, Batch: 3600, Loss: 34.57554244995117
# ['And', ',', 'it', "'s", 'important', 'more', 'more', 'important', ',', '<unk>', '<unk>', '<unk>', '<unk>', '.', '.', '<unk>', '<unk>', '<unk>', '.', '</s>']
# ['<s>', 'Therefore', ',', 'it', 'is', 'all', 'the', 'more', 'important', 'to', 'foster', 'an', 'altruistic', 'motivation', 'rather', 'than', 'a', 'selfish', 'one', '.', '</s>']
# Epoch: 4, Batch: 3700, Loss: 36.16573715209961
# ['But', 'every', 'day', ',', 'we', 'are', 'individuals', 'with', 'are', '<unk>', 'of', 'and', 'stories', 'to', 'they', 'it', 'become', 'made', '.', '</s>', '<pad>']
# ['<s>', 'With', 'every', 'picture', ',', 'there', 'are', 'individuals', 'who', 'have', 'full', 'lives', 'and', 'stories', 'that', 'deserve', 'to', 'be', 'told', '.', '</s>', '<pad>']
# Epoch: 5, Batch: 0, Loss: 20.497079849243164
# ['<unk>', '<unk>', ',', 'I', 'I', 'said', 'said', ',', 'it', 'the', 'to', 'that', 'the', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'institutions', ',', 'as', 'I', "'ve", 'said', ',', 'are', 'prevented', 'from', 'capturing', 'that', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 5, Batch: 100, Loss: 28.790714263916016
# ['I', 'I', 'also', 'also', 'it', '<unk>', 'of', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'and', 'I', 'got', 'into', 'the', 'act', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 5, Batch: 200, Loss: 28.65635108947754
# ['I', '<unk>', 'is', 'to', 'you', 'do', "n't", 'have', 'to', 'do', 'any', 'bad', 'to', 'make', 'at', 'these', 'things', '.', '</s>', '<pad>']
# ['<s>', 'My', 'belief', 'is', 'that', 'you', 'do', "n't", 'have', 'to', 'make', 'yourself', 'bad', 'to', 'look', 'at', 'these', 'issues', '.', '</s>', '<pad>']
# Epoch: 5, Batch: 300, Loss: 25.314363479614258
# ['No', 'No', '.', 'No', '.', 'No', 'one', 'is', '.', 'the', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', '"', 'No', '.', 'No', '.', 'No', 'one', 'is', 'in', 'charge', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 5, Batch: 400, Loss: 26.289012908935547
# ['Let', "'s", 'not', 'talk', 'about', 'it', '-', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Let', "'s", 'not', 'talk', 'about', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 5, Batch: 500, Loss: 31.666614532470703
# ['And', 'that', 'gives', 'us', 'a', 'a', 'factor', 'of', '20', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'that', 'buys', 'us', 'about', 'a', 'factor', 'of', '20', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 5, Batch: 600, Loss: 28.655155181884766
# ['And', 'I', 'looked', 'looking', 'at', 'the', 'lamb', ',', 'say', 'say', ',', '"', 'Albert', ',', 'how', 'long', '?', '</s>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'I', "'m", 'looking', 'at', 'the', 'lamb', 'and', 'I', 'say', ',', '"', 'Albert', ',', 'how', 'long', '?', '</s>', '<pad>', '<pad>', '<pad>']
# Epoch: 5, Batch: 700, Loss: 27.704710006713867
# ['This', 'is', 'Steve', '<unk>', '.', 'Where', 'he', 'he', 'teach', 'with', 'computers', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'This', 'is', 'Steve', '<unk>', '.', 'Where', 'does', 'he', 'learn', 'about', 'computers', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 5, Batch: 800, Loss: 31.055444717407227
# ['PM', ':', 'We', 'we', 'just', 'need', 'to', '<unk>', 'more', 'more', 'more', '.', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'PM', ':', 'And', 'we', 'all', 'need', 'to', 'do', 'a', 'lot', 'more', 'leaning', 'in', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 5, Batch: 900, Loss: 24.252647399902344
# ['It', 'she', 'discovered', 'is', 'through', '<unk>', '<unk>', '<unk>', 'of', 'they', 'was', ',', 'Dr.', 'smoking', '.', '.', '.', '.', '</s>', '<pad>', '<pad>']
# ['<s>', 'What', 'she', 'discovered', 'just', 'by', 'being', 'curiously', 'aware', 'when', 'she', '<unk>', 'was', 'that', 'smoking', 'tastes', 'like', 'shit', '.', '</s>', '<pad>', '<pad>']
# Epoch: 5, Batch: 1000, Loss: 25.371139526367188
# ['These', 'represents', 'of', 'virtual', 'reality', 'is', "n't", 'really', 'good', 'for', 'people', 'people', 'older', 'older', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ...
# ['<s>', 'but', 'really', ',', 'this', 'is', 'what', 'driving', "'s", 'like', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 6, Batch: 3600, Loss: 29.67341423034668
# ['That', 'leads', 'to', 'bad', 'things', 'like', 'like', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'That', 'leads', 'to', 'bad', 'things', ',', 'like', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 6, Batch: 3700, Loss: 27.932802200317383
# ['It', 'she', ',', 'you', 'fact', ',', 'you', "'s", 'was', "n't", 'that', 'the', 'was', 'not', 'possible', '.', 'Internet', '.', "n't", '.', '</s>']
# ['<s>', 'So', 'unusual', ',', 'in', 'fact', ',', 'that', 'it', 'was', 'said', 'that', 'it', "'s", 'not', 'clear', 'the', 'Internet', 'could', 'work', '.', '</s>']
# Epoch: 7, Batch: 0, Loss: 27.376768112182617
# ['And', 'that', "'s", 'what', 'did', 'did', 'did', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'that', 'is', 'what', '<unk>', '<unk>', 'did', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 100, Loss: 24.3299503326416
# ['And', 'will', ',', 'it', 'in', 'and', 'you', 'it', 'saw', 'it', 'the', 'video', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'You', 'then', 'exercise', 'it', ',', 'as', 'what', 'you', 'saw', 'on', 'that', 'tape', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 200, Loss: 31.101669311523438
# ['A', 'goro', 'submission', 'provides', 'appear', 'three', 'meals', 'to', 'a', 'average', 'family', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'One', 'goro', 'goro', 'can', 'feed', 'three', 'meals', 'for', 'an', 'average', 'family', ',', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 300, Loss: 28.532299041748047
# ['And', 'that', 'hope', 'that', 'this', 'optimism', 'optimism', '<unk>', '<unk>', 'year', 'of', '<unk>', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'this', 'hope', ',', 'this', 'optimism', ',', '<unk>', 'a', 'year', 'of', '<unk>', 'transition', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 400, Loss: 23.38067054748535
# ['And', 'lot', 'of', 'space', 'in', 'this', 'room', 'live', 'good', 'good', 'amount', 'of', 'electrons', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'A', 'lot', 'of', 'people', 'in', 'this', 'room', 'make', 'a', 'good', 'living', 'pushing', 'them', 'around', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 500, Loss: 30.639307022094727
# ['I', 'I', 'was', 'chosen', 'to', 'build', 'a', '<unk>', 'from', 'of', '<unk>', '-', ',', '<unk>', 'paper', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'So', 'I', 'was', 'chosen', 'to', 'build', 'the', 'pavilion', 'out', 'of', 'paper', 'tubes', ',', 'recyclable', 'paper', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 600, Loss: 27.066415786743164
# ['So', 'I', 'decided', 'to', 'give', 'to', 'myself', 'give', '.', 'well', 'job', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'So', 'I', 'decided', 'to', 'go', 'there', 'and', 'act', 'as', 'a', 'seller', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 700, Loss: 22.629634857177734
# ['I', 'can', "n't", 'see', ',', 'and', 'I', 'need', 'help', '.', '</s>', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'I', 'ca', "n't", 'see', ',', 'and', 'I', 'need', 'help', '.', '"', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 800, Loss: 26.272958755493164
# ['They', "'re", '<unk>', ',', '<unk>', 'unclear', ']', '.', 'people', 'people', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'They', 'are', '<unk>', ',', '[', 'unclear', ']', ',', '<unk>', 'people', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 900, Loss: 21.451412200927734
# ['The', 'power', 'of', 'the', ',', ',', 'in', 'this', 'part', 'of', 'the', 'world', 'that', 'to', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'The', 'power', 'of', '<unk>', 'so', 'fundamental', 'to', 'that', 'part', 'of', 'the', 'world', 'seems', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 1000, Loss: 22.920564651489258
# ['A', 'a', 'fact', ',', 'the', 'of', 'of', '<unk>', '<unk>', 'boson', 'is', 'called', 'the', '<unk>', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'in', 'particular', ',', 'one', 'area', 'of', 'the', 'temporal', 'lobe', 'is', 'called', 'the', '<unk>', 'gyrus', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 1100, Loss: 28.26949119567871
# ['Because', 'triangles', 'are', 'only', 'only', 'structures', 'structures', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Because', 'triangles', 'are', 'the', 'only', 'rigid', 'structures', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 1200, Loss: 24.380945205688477
# ['<unk>', 'it', 'was', 'the', 'when', 'as', 'as', 'than', '<unk>', 'the', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'nowhere', 'was', 'this', 'brought', 'home', 'more', 'than', 'during', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 1300, Loss: 26.14495086669922
# ['Thank', 'you', 'very', 'much', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Thank', 'you', 'very', 'much', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 1400, Loss: 28.956071853637695
# ['They', 'did', 'this', 'with', 'pigs', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'They', 'did', 'it', 'with', 'pigs', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 1500, Loss: 29.081619262695312
# ['And', 'we', 'can', 'show', 'that', 'the', 'the', ',', "'s", 'pleasant', 'life', 'is', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'we', 'can', 'show', 'in', 'that', 'way', 'that', 'the', 'pleasant', 'life', 'is', 'enhanced', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 1600, Loss: 26.279529571533203
# ['Most', '<unk>', 'the', 'most', '<unk>', 'that', 'are', 'there', ',', 'is', '.', 'actually', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Most', 'of', 'the', 'educational', 'games', 'that', 'are', 'out', 'there', 'today', 'are', 'really', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 1700, Loss: 27.145872116088867
# ['Now', 'black', 'holes', 'are', 'moving', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Both', 'black', 'holes', 'are', 'moving', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 1800, Loss: 28.263473510742188
# ['and', 'that', 'those', 'people', 'are', 'trained', 'trained', ',', 'they', 'collect', 'able', 'the', 'materials', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'So', 'while', 'these', 'people', 'are', 'being', 'trained', ',', 'others', 'are', 'collecting', 'the', 'materials', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 1900, Loss: 27.179765701293945
# ['Even', 'if', 'they', 'ate', "n't", 'eat', 'broccoli', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'But', 'mostly', 'they', 'did', "n't", 'eat', 'broccoli', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 2000, Loss: 25.373022079467773
# ['Now', ',', 'nobody', 'wanted', 'to', 'do', 'my', 'research', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', '<unk>', ',', 'nobody', 'wanted', 'to', 'fund', 'my', 'research', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 2100, Loss: 29.274044036865234
# ['And', 'the', 'as', 'important', ',', 'we', 'owe', 'ourselves', 'to', 'us', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'just', 'as', 'important', ',', 'we', 'owe', 'it', 'to', 'ourselves', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 2200, Loss: 26.72307777404785
# ['And', 'here', 'are', 'some', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'here', 'are', 'some', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 2300, Loss: 30.258708953857422
# ['This', 'is', 'what', 'happens', 'to', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'This', 'is', 'what', 'happens', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 2400, Loss: 27.263280868530273
# ['And', ',', 'I', 'I', 'I', 'think', 'a', 'can', 'tell', 'you', 'a', 'little', 'bit', 'the', 'history', 'of', 'the', '<unk>', '.', '</s>', '<pad>']
# ['<s>', 'And', '...', 'Well', ',', 'I', 'guess', 'I', 'could', 'tell', 'you', 'a', 'little', 'of', 'the', 'history', 'of', 'the', '<unk>', '.', '</s>', '<pad>']
# Epoch: 7, Batch: 2500, Loss: 32.647884368896484
# ['If', 'I', "'m", ',', 'I', "'m", 'come', '<unk>', '.', '.', 'This', 'is', 'the', 'next', 'generation', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'When', 'I', 'eat', ',', 'I', "'ll", 'actually', 'start', 'growing', '.', 'This', 'is', 'the', 'next', 'generation', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 2600, Loss: 29.65309715270996
# ['It', "'s", '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'It', "'s", 'competitive', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 2700, Loss: 31.731855392456055
# ['On', 'this', '<unk>', '<unk>', ',', 'a', 'kind', 'of', '<unk>', ',', 'based', ',', ',', 'we', "'re", 'in', 'in', '</s>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'On', 'that', 'schematic', 'picture', ',', 'a', 'sort', 'of', 'time', '-', 'lapse', 'picture', ',', 'we', "'re", 'halfway', '.', '</s>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 2800, Loss: 22.341169357299805
# ['<unk>', 'is', 'is', 'a', 'great', 'example', 'of', 'this', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', '<unk>', 'Barbie', 'is', 'a', 'great', 'example', 'of', 'that', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 2900, Loss: 27.541296005249023
# ['These', 'people', 'are', 'increasing', 'pollen', 'into', 'a', 'to', 'the', 'on', 'a', 'paintbrush', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'These', 'people', 'are', 'moving', 'pollen', 'from', 'flower', 'to', 'flower', 'with', 'a', 'paintbrush', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 3000, Loss: 33.99802780151367
# ['You', 'know', 'the', 'this', 'solution', 'to', 'this', ',', 'right', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'You', 'do', 'know', 'the', 'solution', 'to', 'that', ',', 'right', '?', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 3100, Loss: 32.44371032714844
# ['And', 'I', 'thought', 'it', 'could', 'be', 'me', 'a', 'kind', 'of', 'kind', '<unk>', '.', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'I', 'thought', 'it', 'might', 'serve', 'as', 'a', 'kind', 'of', 'permanent', '<unk>', 'device', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 3200, Loss: 29.932559967041016
# ['It', 'think', 'it', "'s", '<unk>', 'to', 'be', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'I', 'know', 'there', "'s", 'going', 'to', 'be', 'disbelief', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 3300, Loss: 30.19544219970703
# ['"', 'So', ',', 'Mr.', ',', 'what', 'are', 'you', 'make', 'a', 'nice', 'beautiful', '?', '?', '"', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', '"', 'So', ',', 'Nelson', ',', 'how', 'would', 'you', 'like', 'a', 'nice', 'water', 'feature', '?', '"', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 3400, Loss: 25.834657669067383
# ['They', 'have', ',', 'They', 'have', 'come', 'to', 'to', 'you', 'go', 'at', 'university', 'university', '.', '"', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'You', 'know', '?', 'You', 'can', 'get', '<unk>', 'if', 'you', 'work', 'at', 'a', 'university', '.', '"', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 3500, Loss: 30.026206970214844
# ['I', 'met', 'Andrew', 'on', 'our', 'of', 'our', 'people', '<unk>', 'in', '<unk>', ',', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'I', 'met', 'Andrew', 'at', 'one', 'of', 'our', 'community', 'meetings', 'putting', 'together', '<unk>', '<unk>', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 3600, Loss: 27.234996795654297
# ['And', 'that', 'changed', 'changed', 'changed', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'And', 'this', 'is', 'what', 'changed', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# Epoch: 7, Batch: 3700, Loss: 28.572566986083984
# ['Researchers', 'in', 'Tokyo', 'of', 'it', 'a', 'as', 'a', '<unk>', '<unk>', '-', '<unk>', 'about', '.', 'Tokyo', '.', '</s>', '<pad>', '<pad>', '<pad>']
# ['<s>', 'Researchers', 'in', 'Tokyo', 'are', 'using', 'it', 'as', 'a', 'potential', 'anti', '-', 'theft', 'device', 'in', 'cars', '.', '</s>', '<pad>', '<pad>', '<pad>']

# %%
F.softmax(torch.matmul(rnn_output.squeeze(0),encoder_outputs.transpose(0,1)).squeeze(),dim=0).unsqueeze(0).unsqueeze(0)
# Out:
# tensor([[ 2.6539e-02,  4.2958e-02, -3.3869e-02,  ...,  3.6437e-02,
#           1.6895e-02, -6.5814e-03]], device='cuda:0', grad_fn=<AddmmBackward>)

# %%
encoder_hidden = encoder.init_hidden()
    encoder_outputs, encoder_hidden = encoder(input_variable, encoder_hidden)
    
    # Prepare input and output variables
    decoder_input = Variable(torch.LongTensor([[SOS_token]]))
    decoder_context = Variable(torch.zeros(1, decoder.hidden_size))
    decoder_hidden = encoder_hidden # Use last hidden state from encoder to start decoder
    if USE_CUDA:
        decoder_input = decoder_input.cuda()
        decoder_context = decoder_context.cuda()

    # Choose whether to use teacher forcing
    use_teacher_forcing = random.random() < teacher_forcing_ratio
    if use_teacher_forcing:
        
        # Teacher forcing: Use the ground-truth target as the next input
        for di in range(target_length):
            decoder_output, decoder_context, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_context, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_variable[di])
            decoder_input = target_variable[di]

# %% [markdown]
# ## Submission

# %%
# load test set
sentences = []
for i, l in enumerate(open("source_test.txt"), 1):
  sentences.append(re.split(' ', l))
