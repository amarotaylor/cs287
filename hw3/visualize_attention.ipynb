# %%
import torch
from torch.nn.utils import clip_grad_norm_
torch.__version__
from common import *
import torch.nn.functional as F
import torch.nn as nn
import torch
# Text text processing library and methods for pretrained word embeddings
from torchtext import data, datasets
# Named Tensor wrappers
from namedtensor import ntorch, NamedTensor
from namedtensor.text import NamedField
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ipysankeywidget import SankeyWidget
import scipy
# %reload_ext autoreload

# %autoreload 2

# %%
# split raw data into tokens
import spacy
spacy_de = spacy.load('de')
spacy_en = spacy.load('en')

def tokenize_de(text):
    return [tok.text for tok in spacy_de.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

# add beginning-of-sentence and end-of-sentence tokens to target
BOS_WORD = '<s>'
EOS_WORD = '</s>'
DE = NamedField(names=('srcSeqlen',), tokenize=tokenize_de)
EN = NamedField(names=('trgSeqlen',), tokenize=tokenize_en,
                init_token = BOS_WORD, eos_token = EOS_WORD) # only target needs BOS/EOS

# download dataset of 200K pairs of sentences
# start with MAXLEN = 20
MAX_LEN = 20
train, val, test = datasets.IWSLT.splits(exts=('.de', '.en'), fields=(DE, EN), 
                                         filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and 
                                         len(vars(x)['trg']) <= MAX_LEN)
print(train.fields)
print(len(train))
print(vars(train[0]))

# WHAT DOES THIS DO?
'''src = open("valid.src", "w")
trg = open("valid.trg", "w")
for example in val:
    print(" ".join(example.src), file=src)
    print(" ".join(example.trg), file=trg)
src.close()
trg.close()'''

# build vocab, convert words to indices
MIN_FREQ = 5
DE.build_vocab(train.src, min_freq=MIN_FREQ)
EN.build_vocab(train.trg, min_freq=MIN_FREQ)
print(DE.vocab.freqs.most_common(10))
print("Size of German vocab", len(DE.vocab))
print(EN.vocab.freqs.most_common(10))
print("Size of English vocab", len(EN.vocab))
print(EN.vocab.stoi["<s>"], EN.vocab.stoi["</s>"])

print(EN.vocab.stoi["<pad>"], EN.vocab.stoi["<unk>"])
# split data into batches
BATCH_SIZE = 32
device = torch.device('cuda:0')
train_iter, val_iter = data.BucketIterator.splits((train, val), batch_size=BATCH_SIZE, device=device,
                                                  repeat=False, sort_key=lambda x: len(x.src))
# Out:
# {'src': <namedtensor.text.torch_text.NamedField object at 0x7f8c57a26320>, 'trg': <namedtensor.text.torch_text.NamedField object at 0x7f8c57a26940>}
# 119076
# {'src': ['David', 'Gallo', ':', 'Das', 'ist', 'Bill', 'Lange', '.', 'Ich', 'bin', 'Dave', 'Gallo', '.'], 'trg': ['David', 'Gallo', ':', 'This', 'is', 'Bill', 'Lange', '.', 'I', "'m", 'Dave', 'Gallo', '.']}
# [('.', 113253), (',', 67237), ('ist', 24189), ('die', 23778), ('das', 17102), ('der', 15727), ('und', 15622), ('Sie', 15085), ('es', 13197), ('ich', 12946)]
# Size of German vocab 13353
# [('.', 113433), (',', 59512), ('the', 46029), ('to', 29177), ('a', 27548), ('of', 26794), ('I', 24887), ('is', 21775), ("'s", 20630), ('that', 19814)]
# Size of English vocab 11560
# 2 3
# 1 0

# %%
context_size = 500
num_layers = 2
attn_context2trg = attn_RNNet_batched(input_size=len(EN.vocab),hidden_size=context_size,num_layers=num_layers)
seq2context = SequenceModel(len(DE.vocab),context_size,num_layers=num_layers)

state_dict = torch.load('best_seq2seq_withattn_context2trg.pt')
attn_context2trg.load_state_dict(state_dict)
state_dict = torch.load('best_seq2seq_withattn_seq2context.pt')
seq2context.load_state_dict(state_dict)
attn_context2trg = attn_context2trg.cuda()
seq2context = seq2context.cuda()

attn_context2trg_optimizer = torch.optim.Adam(attn_context2trg.parameters(), lr=1e-3)
seq2context_optimizer = torch.optim.Adam(seq2context.parameters(), lr=1e-3)
scheduler_c2t = torch.optim.lr_scheduler.ReduceLROnPlateau(attn_context2trg_optimizer, mode="min", patience=4)
scheduler_s2c = torch.optim.lr_scheduler.ReduceLROnPlateau(seq2context_optimizer, mode="min", patience=4)

# %%
ppl = attn_validation_loop(0,val_iter,seq2context,attn_context2trg,scheduler_c2t,scheduler_s2c,BATCH_SIZE=32,context_size=500)
# Out:
# Epoch: 0, Validation PPL: 4.14863920211792

# %%
for ix,batch in enumerate(val_iter):        
        src = batch.src.values.transpose(0,1)
        src = reverse_sequence(src)
        trg = batch.trg.values.transpose(0,1)
        if ix==2:
            break

# %%
encoder_outputs, encoder_hidden = seq2context(src)
decoder_context = torch.zeros(BATCH_SIZE, context_size, device='cuda') # 32 x 500
decoder_hidden = encoder_hidden

# %%
outputs = []
attns = []
for j in range(trg.shape[1] - 1):
            word_input = trg[:,j]
            decoder_output, decoder_context, decoder_hidden, decoder_attention = attn_context2trg(word_input, decoder_context, decoder_hidden, encoder_outputs)
            outputs.append(decoder_output)
            attns.append(decoder_attention)

# %%
batch_attend = torch.stack(attns)

# %%
s_trg = trg[10,:-1]
s_src = src[10,:]
print(s_trg,s_src)
# Out:
# tensor([   2,   24,    5, 9359,   36,  676,    4,    3,    1,    1,    1,    1,
#            1], device='cuda:0') tensor([  1,   2, 833,  59,   0,   3,  73], device='cuda:0')

# %%
print((' '.join([EN.vocab.itos[w] for w in s_trg])))
print((' '.join([DE.vocab.itos[w] for w in s_src])))
attention_matrix = batch_attend[:,10,0,:].detach().cpu().numpy()
# Out:
# <s> So , Superman can fly . </s> <pad> <pad> <pad> <pad> <pad>
# <pad> . fliegen kann <unk> , Also

# %%
def visualize_attention(attention_matrix,s_trg,s_src):
    df = pd.DataFrame(columns = ['source','target','type','value'] )
    source = []
    target = []
    ty = []
    value = []
    attn = softmax(attention_matrix,axis=1)
    duplicates = dict()
    for ix,i in enumerate(s_trg):
        # skip padding
        if i != 1 and i!=4 and i!=21: 
            for jx,j in enumerate(s_src):
                if j != 1 and j!=2 and j!=3 and j!=0:
                    source.append(DE.vocab.itos[j])
                    target.append(EN.vocab.itos[i])
                    ty.append(EN.vocab.itos[i])
                    value.append(attn[ix,jx]*100)
    df['source'] = source
    df['target'] = target
    df['type'] = ty
    df['value'] = value
    #SankeyWidget(links=df.to_dict('records'))
    return df

# %%
df = visualize_attention(attention_matrix,s_trg,s_src)

# %%
SankeyWidget(links=df.to_dict('records'))
# Out:
# SankeyWidget(links=[{'source': 'fliegen', 'target': '<s>', 'type': '<s>', 'value': 7.539398223161697}, {'sourc…

# %%
# Out:
# [{'source': '<s>',
#   'target': 'Aufklärung',
#   'type': '<s>',
#   'value': 5.031529441475868},
#  {'source': '<s>',
#   'target': 'und',
#   'type': '<s>',
#   'value': 5.8494411408901215},
#  {'source': '<s>',
#   'target': '<unk>',
#   'type': '<s>',
#   'value': 6.420550495386124},
#  {'source': '<s>',
#   'target': 'durch',
#   'type': '<s>',
#   'value': 8.476591855287552},
#  {'source': '<s>',
#   'target': 'hilft',
#   'type': '<s>',
#   'value': 6.7545779049396515},
#  {'source': '<s>', 'target': 'und', 'type': '<s>', 'value': 7.14527815580368},
#  {'source': '<s>',
#   'target': 'sich',
#   'type': '<s>',
#   'value': 5.647348240017891},
#  {'source': '<s>',
#   'target': 'engagiert',
#   'type': '<s>',
#   'value': 6.4884185791015625},
#  {'source': '<s>',
#   'target': 'Schule',
#   'type': '<s>',
#   'value': 6.244835257530212},
#  {'source': '<s>', 'target': 'neue', 'type': '<s>', 'value': 9.90273803472519},
#  {'source': '<s>',
#   'target': 'Meine',
#   'type': '<s>',
#   'value': 22.548110783100128},
#  {'source': 'My',
#   'target': 'Aufklärung',
#   'type': 'My',
#   'value': 1.6647826880216599},
#  {'source': 'My', 'target': 'und', 'type': 'My', 'value': 1.379946619272232},
#  {'source': 'My',
#   'target': '<unk>',
#   'type': 'My',
#   'value': 1.5151326544582844},
#  {'source': 'My', 'target': 'durch', 'type': 'My', 'value': 1.861364208161831},
#  {'source': 'My',
#   'target': 'hilft',
#   'type': 'My',
#   'value': 1.3567551039159298},
#  {'source': 'My', 'target': 'und', 'type': 'My', 'value': 2.184252254664898},
#  {'source': 'My', 'target': 'sich', 'type': 'My', 'value': 1.8708931282162666},
#  {'source': 'My',
#   'target': 'engagiert',
#   'type': 'My',
#   'value': 2.790883742272854},
#  {'source': 'My',
#   'target': 'Schule',
#   'type': 'My',
#   'value': 7.496962696313858},
#  {'source': 'My', 'target': 'neue', 'type': 'My', 'value': 25.86962878704071},
#  {'source': 'My',
#   'target': 'Meine',
#   'type': 'My',
#   'value': 50.158143043518066},
#  {'source': 'new',
#   'target': 'Aufklärung',
#   'type': 'new',
#   'value': 4.573460295796394},
#  {'source': 'new',
#   'target': 'und',
#   'type': 'new',
#   'value': 1.0219019837677479},
#  {'source': 'new',
#   'target': '<unk>',
#   'type': 'new',
#   'value': 2.362164482474327},
#  {'source': 'new',
#   'target': 'durch',
#   'type': 'new',
#   'value': 0.7634586654603481},
#  {'source': 'new',
#   'target': 'hilft',
#   'type': 'new',
#   'value': 2.1473340690135956},
#  {'source': 'new', 'target': 'und', 'type': 'new', 'value': 4.327612742781639},
#  {'source': 'new',
#   'target': 'sich',
#   'type': 'new',
#   'value': 3.567107766866684},
#  {'source': 'new',
#   'target': 'engagiert',
#   'type': 'new',
#   'value': 8.245589584112167},
#  {'source': 'new',
#   'target': 'Schule',
#   'type': 'new',
#   'value': 38.08651864528656},
#  {'source': 'new',
#   'target': 'neue',
#   'type': 'new',
#   'value': 22.788415849208832},
#  {'source': 'new',
#   'target': 'Meine',
#   'type': 'new',
#   'value': 10.284937918186188},
#  {'source': 'school',
#   'target': 'Aufklärung',
#   'type': 'school',
#   'value': 2.366657741367817},
#  {'source': 'school',
#   'target': 'und',
#   'type': 'school',
#   'value': 4.279956594109535},
#  {'source': 'school',
#   'target': '<unk>',
#   'type': 'school',
#   'value': 3.1216543167829514},
#  {'source': 'school',
#   'target': 'durch',
#   'type': 'school',
#   'value': 2.736211009323597},
#  {'source': 'school',
#   'target': 'hilft',
#   'type': 'school',
#   'value': 14.170841872692108},
#  {'source': 'school',
#   'target': 'und',
#   'type': 'school',
#   'value': 6.95892870426178},
#  {'source': 'school',
#   'target': 'sich',
#   'type': 'school',
#   'value': 12.002845853567123},
#  {'source': 'school',
#   'target': 'engagiert',
#   'type': 'school',
#   'value': 30.790019035339355},
#  {'source': 'school',
#   'target': 'Schule',
#   'type': 'school',
#   'value': 10.0156269967556},
#  {'source': 'school',
#   'target': 'neue',
#   'type': 'school',
#   'value': 6.7292287945747375},
#  {'source': 'school',
#   'target': 'Meine',
#   'type': 'school',
#   'value': 4.212640225887299},
#  {'source': 'now',
#   'target': 'Aufklärung',
#   'type': 'now',
#   'value': 4.113674163818359},
#  {'source': 'now', 'target': 'und', 'type': 'now', 'value': 4.054874554276466},
#  {'source': 'now',
#   'target': '<unk>',
#   'type': 'now',
#   'value': 3.945137932896614},
#  {'source': 'now',
#   'target': 'durch',
#   'type': 'now',
#   'value': 2.7853863313794136},
#  {'source': 'now',
#   'target': 'hilft',
#   'type': 'now',
#   'value': 24.42268580198288},
#  {'source': 'now', 'target': 'und', 'type': 'now', 'value': 4.943499341607094},
#  {'source': 'now',
#   'target': 'sich',
#   'type': 'now',
#   'value': 9.571294486522675},
#  {'source': 'now',
#   'target': 'engagiert',
#   'type': 'now',
#   'value': 29.457226395606995},
#  {'source': 'now',
#   'target': 'Schule',
#   'type': 'now',
#   'value': 6.760107725858688},
#  {'source': 'now',
#   'target': 'neue',
#   'type': 'now',
#   'value': 4.076238349080086},
#  {'source': 'now',
#   'target': 'Meine',
#   'type': 'now',
#   'value': 2.9000671580433846},
#  {'source': 'is',
#   'target': 'Aufklärung',
#   'type': 'is',
#   'value': 6.759662181138992},
#  {'source': 'is', 'target': 'und', 'type': 'is', 'value': 5.934585258364677},
#  {'source': 'is',
#   'target': '<unk>',
#   'type': 'is',
#   'value': 5.8691684156656265},
#  {'source': 'is', 'target': 'durch', 'type': 'is', 'value': 6.966705620288849},
#  {'source': 'is',
#   'target': 'hilft',
#   'type': 'is',
#   'value': 13.287502527236938},
#  {'source': 'is', 'target': 'und', 'type': 'is', 'value': 5.969533324241638},
#  {'source': 'is', 'target': 'sich', 'type': 'is', 'value': 15.572972595691681},
#  {'source': 'is',
#   'target': 'engagiert',
#   'type': 'is',
#   'value': 22.38946706056595},
#  {'source': 'is',
#   'target': 'Schule',
#   'type': 'is',
#   'value': 7.273245602846146},
#  {'source': 'is', 'target': 'neue', 'type': 'is', 'value': 3.1232276931405067},
#  {'source': 'is', 'target': 'Meine', 'type': 'is', 'value': 2.537836879491806},
#  {'source': 'coming',
#   'target': 'Aufklärung',
#   'type': 'coming',
#   'value': 4.506342858076096},
#  {'source': 'coming',
#   'target': 'und',
#   'type': 'coming',
#   'value': 6.897088885307312},
#  {'source': 'coming',
#   'target': '<unk>',
#   'type': 'coming',
#   'value': 5.762207880616188},
#  {'source': 'coming',
#   'target': 'durch',
#   'type': 'coming',
#   'value': 17.104017734527588},
#  {'source': 'coming',
#   'target': 'hilft',
#   'type': 'coming',
#   'value': 12.228289246559143},
#  {'source': 'coming',
#   'target': 'und',
#   'type': 'coming',
#   'value': 8.575896918773651},
#  {'source': 'coming',
#   'target': 'sich',
#   'type': 'coming',
#   'value': 13.215826451778412},
#  {'source': 'coming',
#   'target': 'engagiert',
#   'type': 'coming',
#   'value': 11.122588068246841},
#  {'source': 'coming',
#   'target': 'Schule',
#   'type': 'coming',
#   'value': 7.032768428325653},
#  {'source': 'coming',
#   'target': 'neue',
#   'type': 'coming',
#   'value': 4.684893041849136},
#  {'source': 'coming',
#   'target': 'Meine',
#   'type': 'coming',
#   'value': 3.887215256690979},
#  {'source': 'in',
#   'target': 'Aufklärung',
#   'type': 'in',
#   'value': 6.01227879524231},
#  {'source': 'in', 'target': 'und', 'type': 'in', 'value': 4.354236647486687},
#  {'source': 'in', 'target': '<unk>', 'type': 'in', 'value': 6.056984141469002},
#  {'source': 'in',
#   'target': 'durch',
#   'type': 'in',
#   'value': 19.472405314445496},
#  {'source': 'in',
#   'target': 'hilft',
#   'type': 'in',
#   'value': 12.310612946748734},
#  {'source': 'in', 'target': 'und', 'type': 'in', 'value': 7.184506207704544},
#  {'source': 'in', 'target': 'sich', 'type': 'in', 'value': 11.822853982448578},
#  {'source': 'in',
#   'target': 'engagiert',
#   'type': 'in',
#   'value': 9.455934166908264},
#  {'source': 'in',
#   'target': 'Schule',
#   'type': 'in',
#   'value': 10.000599175691605},
#  {'source': 'in', 'target': 'neue', 'type': 'in', 'value': 5.454553663730621},
#  {'source': 'in', 'target': 'Meine', 'type': 'in', 'value': 4.636045545339584},
#  {'source': 'and',
#   'target': 'Aufklärung',
#   'type': 'and',
#   'value': 7.7377550303936005},
#  {'source': 'and', 'target': 'und', 'type': 'and', 'value': 18.81890445947647},
#  {'source': 'and',
#   'target': '<unk>',
#   'type': 'and',
#   'value': 4.191751405596733},
#  {'source': 'and',
#   'target': 'durch',
#   'type': 'and',
#   'value': 7.3609501123428345},
#  {'source': 'and',
#   'target': 'hilft',
#   'type': 'and',
#   'value': 14.754574000835419},
#  {'source': 'and',
#   'target': 'und',
#   'type': 'and',
#   'value': 25.870469212532043},
#  {'source': 'and', 'target': 'sich', 'type': 'and', 'value': 4.59258109331131},
#  {'source': 'and',
#   'target': 'engagiert',
#   'type': 'and',
#   'value': 4.451744258403778},
#  {'source': 'and',
#   'target': 'Schule',
#   'type': 'and',
#   'value': 4.9254149198532104},
#  {'source': 'and',
#   'target': 'neue',
#   'type': 'and',
#   'value': 2.8917379677295685},
#  {'source': 'and',
#   'target': 'Meine',
#   'type': 'and',
#   'value': 1.8859338015317917},
#  {'source': 'helping',
#   'target': 'Aufklärung',
#   'type': 'helping',
#   'value': 8.779332786798477},
#  {'source': 'helping',
#   'target': 'und',
#   'type': 'helping',
#   'value': 10.329785943031311},
#  {'source': 'helping',
#   'target': '<unk>',
#   'type': 'helping',
#   'value': 8.297067880630493},
#  {'source': 'helping',
#   'target': 'durch',
#   'type': 'helping',
#   'value': 17.212186753749847},
#  {'source': 'helping',
#   'target': 'hilft',
#   'type': 'helping',
#   'value': 11.087969690561295},
#  {'source': 'helping',
#   'target': 'und',
#   'type': 'helping',
#   'value': 9.959374368190765},
#  {'source': 'helping',
#   'target': 'sich',
#   'type': 'helping',
#   'value': 6.123767048120499},
#  {'source': 'helping',
#   'target': 'engagiert',
#   'type': 'helping',
#   'value': 4.922063648700714},
#  {'source': 'helping',
#   'target': 'Schule',
#   'type': 'helping',
#   'value': 5.640061572194099},
#  {'source': 'helping',
#   'target': 'neue',
#   'type': 'helping',
#   'value': 5.877828225493431},
#  {'source': 'helping',
#   'target': 'Meine',
#   'type': 'helping',
#   'value': 6.645715236663818},
#  {'source': 'by',
#   'target': 'Aufklärung',
#   'type': 'by',
#   'value': 8.728091418743134},
#  {'source': 'by', 'target': 'und', 'type': 'by', 'value': 7.592897117137909},
#  {'source': 'by', 'target': '<unk>', 'type': 'by', 'value': 9.676831215620041},
#  {'source': 'by', 'target': 'durch', 'type': 'by', 'value': 29.7650009393692},
#  {'source': 'by',
#   'target': 'hilft',
#   'type': 'by',
#   'value': 11.523500829935074},
#  {'source': 'by', 'target': 'und', 'type': 'by', 'value': 6.813015788793564},
#  {'source': 'by', 'target': 'sich', 'type': 'by', 'value': 4.275670647621155},
#  {'source': 'by',
#   'target': 'engagiert',
#   'type': 'by',
#   'value': 3.6495771259069443},
#  {'source': 'by',
#   'target': 'Schule',
#   'type': 'by',
#   'value': 4.227396100759506},
#  {'source': 'by', 'target': 'neue', 'type': 'by', 'value': 4.190326854586601},
#  {'source': 'by', 'target': 'Meine', 'type': 'by', 'value': 5.047156289219856},
#  {'source': 'fundraising',
#   'target': 'Aufklärung',
#   'type': 'fundraising',
#   'value': 8.010273426771164},
#  {'source': 'fundraising',
#   'target': 'und',
#   'type': 'fundraising',
#   'value': 14.071211218833923},
#  {'source': 'fundraising',
#   'target': '<unk>',
#   'type': 'fundraising',
#   'value': 12.877026200294495},
#  {'source': 'fundraising',
#   'target': 'durch',
#   'type': 'fundraising',
#   'value': 13.72048407793045},
#  {'source': 'fundraising',
#   'target': 'hilft',
#   'type': 'fundraising',
#   'value': 9.81932282447815},
#  {'source': 'fundraising',
#   'target': 'und',
#   'type': 'fundraising',
#   'value': 7.229812443256378},
#  {'source': 'fundraising',
#   'target': 'sich',
#   'type': 'fundraising',
#   'value': 5.9770867228508},
#  {'source': 'fundraising',
#   'target': 'engagiert',
#   'type': 'fundraising',
#   'value': 5.46240322291851},
#  {'source': 'fundraising',
#   'target': 'Schule',
#   'type': 'fundraising',
#   'value': 5.091242864727974},
#  {'source': 'fundraising',
#   'target': 'neue',
#   'type': 'fundraising',
#   'value': 5.976876989006996},
#  {'source': 'fundraising',
#   'target': 'Meine',
#   'type': 'fundraising',
#   'value': 5.5159978568553925},
#  {'source': 'and',
#   'target': 'Aufklärung',
#   'type': 'and',
#   'value': 13.045991957187653},
#  {'source': 'and',
#   'target': 'und',
#   'type': 'and',
#   'value': 29.618260264396667},
#  {'source': 'and',
#   'target': '<unk>',
#   'type': 'and',
#   'value': 6.190618500113487},
#  {'source': 'and', 'target': 'durch', 'type': 'and', 'value': 9.5662921667099},
#  {'source': 'and',
#   'target': 'hilft',
#   'type': 'and',
#   'value': 9.159568697214127},
#  {'source': 'and',
#   'target': 'und',
#   'type': 'and',
#   'value': 11.131846904754639},
#  {'source': 'and',
#   'target': 'sich',
#   'type': 'and',
#   'value': 2.929169684648514},
#  {'source': 'and',
#   'target': 'engagiert',
#   'type': 'and',
#   'value': 3.986074775457382},
#  {'source': 'and',
#   'target': 'Schule',
#   'type': 'and',
#   'value': 4.1412752121686935},
#  {'source': 'and',
#   'target': 'neue',
#   'type': 'and',
#   'value': 4.156477004289627},
#  {'source': 'and',
#   'target': 'Meine',
#   'type': 'and',
#   'value': 2.9296116903424263},
#  {'source': 'creating',
#   'target': 'Aufklärung',
#   'type': 'creating',
#   'value': 23.511256277561188},
#  {'source': 'creating',
#   'target': 'und',
#   'type': 'creating',
#   'value': 24.29826259613037},
#  {'source': 'creating',
#   'target': '<unk>',
#   'type': 'creating',
#   'value': 6.0470182448625565},
#  {'source': 'creating',
#   'target': 'durch',
#   'type': 'creating',
#   'value': 5.830415710806847},
#  {'source': 'creating',
#   'target': 'hilft',
#   'type': 'creating',
#   'value': 5.697957426309586},
#  {'source': 'creating',
#   'target': 'und',
#   'type': 'creating',
#   'value': 4.598451405763626},
#  {'source': 'creating',
#   'target': 'sich',
#   'type': 'creating',
#   'value': 3.5256277769804},
#  {'source': 'creating',
#   'target': 'engagiert',
#   'type': 'creating',
#   'value': 4.250185564160347},
#  {'source': 'creating',
#   'target': 'Schule',
#   'type': 'creating',
#   'value': 5.404478684067726},
#  {'source': 'creating',
#   'target': 'neue',
#   'type': 'creating',
#   'value': 7.455626875162125},
#  {'source': 'creating',
#   'target': 'Meine',
#   'type': 'creating',
#   'value': 5.074964463710785},
#  {'source': 'an',
#   'target': 'Aufklärung',
#   'type': 'an',
#   'value': 19.900359213352203},
#  {'source': 'an', 'target': 'und', 'type': 'an', 'value': 22.094762325286865},
#  {'source': 'an', 'target': '<unk>', 'type': 'an', 'value': 9.470265358686447},
#  {'source': 'an', 'target': 'durch', 'type': 'an', 'value': 7.665705680847168},
#  {'source': 'an', 'target': 'hilft', 'type': 'an', 'value': 7.957934588193893},
#  {'source': 'an', 'target': 'und', 'type': 'an', 'value': 9.141059964895248},
#  {'source': 'an', 'target': 'sich', 'type': 'an', 'value': 3.097817488014698},
#  {'source': 'an',
#   'target': 'engagiert',
#   'type': 'an',
#   'value': 4.2186737060546875},
#  {'source': 'an',
#   'target': 'Schule',
#   'type': 'an',
#   'value': 2.974221669137478},
#  {'source': 'an', 'target': 'neue', 'type': 'an', 'value': 5.575766041874886},
#  {'source': 'an', 'target': 'Meine', 'type': 'an', 'value': 3.557814657688141},
#  {'source': 'awareness',
#   'target': 'Aufklärung',
#   'type': 'awareness',
#   'value': 12.962561845779419},
#  {'source': 'awareness',
#   'target': 'und',
#   'type': 'awareness',
#   'value': 9.655079245567322},
#  {'source': 'awareness',
#   'target': '<unk>',
#   'type': 'awareness',
#   'value': 8.598332852125168},
#  {'source': 'awareness',
#   'target': 'durch',
#   'type': 'awareness',
#   'value': 7.969687134027481},
#  {'source': 'awareness',
#   'target': 'hilft',
#   'type': 'awareness',
#   'value': 12.144027650356293},
#  {'source': 'awareness',
#   'target': 'und',
#   'type': 'awareness',
#   'value': 5.685022100806236},
#  {'source': 'awareness',
#   'target': 'sich',
#   'type': 'awareness',
#   'value': 2.9454706236720085},
#  {'source': 'awareness',
#   'target': 'engagiert',
#   'type': 'awareness',
#   'value': 5.397836118936539},
#  {'source': 'awareness',
#   'target': 'Schule',
#   'type': 'awareness',
#   'value': 13.453209400177002},
#  {'source': 'awareness',
#   'target': 'neue',
#   'type': 'awareness',
#   'value': 9.586706757545471},
#  {'source': 'awareness',
#   'target': 'Meine',
#   'type': 'awareness',
#   'value': 7.48586505651474},
#  {'source': '</s>',
#   'target': 'Aufklärung',
#   'type': '</s>',
#   'value': 6.602469086647034},
#  {'source': '</s>',
#   'target': 'und',
#   'type': '</s>',
#   'value': 7.144568860530853},
#  {'source': '</s>',
#   'target': '<unk>',
#   'type': '</s>',
#   'value': 9.452059119939804},
#  {'source': '</s>',
#   'target': 'durch',
#   'type': '</s>',
#   'value': 4.581133276224136},
#  {'source': '</s>',
#   'target': 'hilft',
#   'type': '</s>',
#   'value': 24.82498586177826},
#  {'source': '</s>',
#   'target': 'und',
#   'type': '</s>',
#   'value': 6.88193216919899},
#  {'source': '</s>',
#   'target': 'sich',
#   'type': '</s>',
#   'value': 3.4667905420064926},
#  {'source': '</s>',
#   'target': 'engagiert',
#   'type': '</s>',
#   'value': 6.390251964330673},
#  {'source': '</s>',
#   'target': 'Schule',
#   'type': '</s>',
#   'value': 9.046506136655807},
#  {'source': '</s>',
#   'target': 'neue',
#   'type': '</s>',
#   'value': 12.031091749668121},
#  {'source': '</s>',
#   'target': 'Meine',
#   'type': '</s>',
#   'value': 7.337936758995056}]

# %%
ordering = [
    ['farms'],       # put "farms" on the left...
    ['customers'],   # ... and "customers" on the right.
]

# %%
bundles = [
    Bundle('farms', 'customers'),
]

# %%
sdd = SankeyDefinition(nodes, bundles, ordering)
weave(sdd, flows).to_widget(**size)
# Out:
# SankeyWidget(layout=Layout(height='300', width='570'), links=[{'source': 'farms^*', 'target': 'customers^*', '…

# %%
w = weave(sdd, flows).to_widget(**size)

# %%
w
# Out:
# SankeyWidget(layout=Layout(height='300', width='570'), links=[{'source': 'farms^*', 'target': 'customers^*', '…
